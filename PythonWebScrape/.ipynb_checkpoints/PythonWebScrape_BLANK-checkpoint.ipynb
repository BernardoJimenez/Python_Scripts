# %% [markdown]
# # Python Web-Scraping
#
# **Topics**
#
# * Web basics
# * Making web requests
# * Inspecting web sites
# * Retrieving web data
# * Using Xpaths to retrieve `html` content
# * Parsing `html` content
# * Cleaning and storing text from `html`

# %% [markdown]
# ## Setup
#
# ### Software and Materials
#
# Follow the [Python Installation](./PythonInstall.html) instructions and ensure that you can successfully start JupyterLab.

# %% [markdown]
# ### Class Structure
#
# Informal - Ask questions at any time. Really!
#
# Collaboration is encouraged - please spend a minute introducing yourself to your neighbors!

# %% [markdown]
# ### Prerequisites
#
# This is an intermediate / advanced Python course:
#
# * Assumes knowledge of Python, including:
#     + lists
#     + dictionaries
#     + logical indexing
#     + iteration with for-loops
# * Assumes basic knowledge of web page structure
# * Relatively fast-paced
#
# If you need an introduction to Python or a refresher, we recommend our
# [Python Introduction](https://iqss.github.io/dss-workshops/PythonIntro.html).

# %% [markdown]
# ### Goals
#
# <div class="alert alert-success">
# This workshop is organized into two main parts:
#
# 1. Retrive information in JSON format
# 2. Parse HTML files
#
# Note that this workshop will not teach you everything you need to know in
# order to retrieve data from any web service you might wish to scrape.
# </div>

# %% [markdown]
# ## Webscraping background
#
# ### What is web scraping?
#
# Web scraping is the activity of automating retrieval of information
# from a web service designed for human interaction.
#
# ### Is web scraping legal? Is it ethical?
#
# It depends. If you have legal questions seek legal counsel. You can
# mitigate some ethical issues by building delays and restrictions into
# your web scraping program so as to avoid impacting the availability of
# the web service for other users or the cost of hosting the service for
# the service provider.
#
# ### Web scraping approaches
#
# No two websites are identical --- websites are built for different purposes by different people
# and so have different underlying structures. Because they are heterogeneous, there is no single way to
# scrape a website. **The scraping approach therefore has to be tailored to each individual site.**
# Here are some commonly used approaches:
#
# 1. Use requests to extract information from structured JSON files
# 2. Use requests to extract information from HTML
# 3. Automate a browser to retrieve information from HTML
#
# Bear in mind that even once you've decided upon the best approach for a particular site,
# it will be necessary to modified that approach to suit your particular use-case.
#
# ### How does the web work?
#
# #### Components
#
# Computers connected to the web are called **clients** and **servers**. A simplified diagram of how they interact might look like this:
#
# ![](images/client_server.png)
#
# * **Clients** are the typical web user's internet-connected devices (for example, your computer connected to your Wi-Fi) and web-accessing software available on those devices (usually a web browser like Firefox or Chrome).
# * **Servers** are computers that store webpages, sites, or apps. When a client device wants to access a webpage, a copy of the webpage is downloaded from the server onto the client machine to be displayed in the user's web browser.
# * **HTTP** is a language for clients and servers to speak to each other.
#
# #### So What Happens?
#
# When you type a web address into your browser:
#
# 1. The browser finds the address of the server that the website lives on.
# 2. The browser sends an **HTTP request message** to the server, asking it to send a copy of the website to the client.
# 3. If the server approves the client's request, the server sends the client a "200 OK" message, and then starts displaying the website in the browser.

# %% [markdown]
# ## Retrieve data in JSON format if you can
#
# <div class="alert alert-info">
# **GOAL: To retrieve information in JSON format and organize it into a spreadsheet.**
#
# 1. Inspect the website to check if the content is stored in JSON format
# 2. Make a request to the website server to retrieve the JSON file
# 3. Convert from JSON format into a Python dictionary
# 4. Extract the data from the dictionary and store in a .csv file
# </div>
#
# We wish to extract information from
# <https://www.harvardartmuseums.org/collections>. Like most
# modern web pages, a lot goes on behind the scenes to produce the page
# we see in our browser. Our goal is to pull back the curtain to see
# what the website does when we interact with it. Once we see how the
# website works we can start retrieving data from it.
#
# If we are lucky we'll find a resource that returns the data we're
# looking for in a structured format like [JSON](https://json.org/).
#
# ![](images/json-format.png)
#
# This is useful because it is very easy to convert data from JSON or XML
# into a spreadsheet type format --- like a csv or Excel file.
#
# ### Examine the website's structure
#
# The basic strategy is pretty much the same for most scraping projects.
# We will use our web browser (Chrome or Firefox recommended) to examine
# the page you wish to retrieve data from, and copy/paste information
# from your web browser into your scraping program.
#
# We start by opening the collections web page in a web browser and
# inspecting it.
#
# ![](images/dev_tools.png)
#
# ![](images/dev_tools_pane.png)
#
# If we scroll down to the bottom of the Collections page, we'll see a
# button that says "Load More". Let's see what happens when we click on
# that button. To do so, click on "Network" in the developer tools
# window, then click the "Load More Collections" button. You should see
# a list of requests that were made as a result of clicking that button,
# as shown below.
#
# ![](images/dev_tools_network.png)

# %% [markdown]
# If we look at that second request, the one to a script named
# `browse`, we'll see that it returns all the information we need, in
# a convenient format called `JSON`. All we need to retrieve collection
# data is call make `GET` requests to
# <https://www.harvardartmuseums.org/browse> with the correct
# parameters.
#
# ### Launch JupyterLab
#
# 1. Start the `Anaconda Navigator` program
# 2. Click the `Launch` button under `Jupyter Lab`
# 3. A browser window will open with your computer's files listed on the left hand side of the page. Navigate to the folder called `PythonWebScrape` that you downloaded to your desktop and double-click on the folder
# 4. Within the `PythonWebScrape` folder, double-click on the file with the word "BLANK" in the name (`PythonWebScrape_BLANK.ipynb`). A pop-up window will ask you to `Select Kernal` --- you should select the Python 3 kernal. The Jupyter Notebook should now open on the right hand side of the page
#
# A Jupyter Notebook contains one or more *cells* containing notes or code. To insert a new cell click the `+` button in the upper left. To execute a cell, select it and press `Control+Enter` or click the `Run` button at the top.

# %%
## This sets some printing options
## that make output look nicer.

from pprint import pprint as print
import pandas as pd
pd.set_option('display.width', 133)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_columns', 5)

# %% [markdown]
# ### Making requests
#
# To retrieve information from the website (i.e., make a request),
# we need to know the location of the information we want to collect.
# The Uniform Resource Locator (URL) --- commonly know as a "web address",
# specifies the location of a resource (such as a web page) on the internet.
#
# A URL is usually composed of 5 parts:
#
# ![](images/URL.png)
#
# The 4th part, the "query string", contains one or more **parameters**.
# The 5th part, the "fragment", is an internal page reference and may not be present.
#
# For example, the URL we want to retrieve data from has the following structure:
#
#     protocol                    domain    path  parameters
#        https www.harvardartmuseums.org  browse  load_amount=10&offset=0
#
# It is often convenient to create variables containing the domain(s)
# and path(s) you'll be working with, as this allows you to swap out
# paths and parameters as needed. Note that the path is separated from
# the domain with `/` and the parameters are separated from the path
# with `?`. If there are multiple parameters they are separated from
# each other with a `&`.
#
# For example, we can define the domain and path of the collections URL
# as follows:

# %%
museum_domain = 'https://www.harvardartmuseums.org'

collection_path = 'browse'

collection_url = (museum_domain
                  +
                  '/'
                  +
                  collection_path)

print(collection_url)
# Out:
# https://www.harvardartmuseums.org/browse

# %% [markdown]
# Note that we omit the parameters here because it is usually easier to
# pass them as a `dict` when using the `requests` library in Python.
# This will become clearer shortly.
#
# Now that we've constructed the URL we wish interact with we're ready
# to make our first request in Python.

# %%
import requests

harvard_params = {'load_amount': 10, 'offset': 0}

r = requests.get(collection_url, params=harvard_params)

print(r.url)
# Out:
# https://harvardartmuseums.org/browse?load_amount=10&offset=0

# %% [markdown]
# Note that the parameters `load_amount` and `offset` are essentially
# another way of setting page numbers --- they refer to the amount of
# information retrieved at one time and the starting position, respectively.
#
# ### Parsing JSON data
#
# We already know from inspecting network traffic in our web
# browser that this URL returns JSON, but we can use Python
# to verify this assumption.

# %%
#r.json()
r.headers['Content-Type']
# Out:
# 'application/json'

# %% [markdown]
# Since JSON is a structured data format, parsing it into Python data
# structures is easy. In fact, there's a method for that!

# %%
print(r.json())
# Out:
# {'info': {'next': 'https://api.harvardartmuseums.org/object?apikey=67d9edc0-e6a3-11e3-9798-57275476509a&sort=rank&sortorder=asc&from=0&size=10&page=2',
#           'page': 1,
#           'pages': 23970,
#           'totalrecords': 239695,
#           'totalrecordsperquery': 10},
#  'records': [{'accessionmethod': 'Gift',
#               'accessionyear': 1994,
#               'accesslevel': 1,
#               'century': '1st-2nd century CE',
#               'classification': 'Vessels',
#               'classificationid': 57,
#               'colorcount': 0,
#               'commentary': None,
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'Gift of the Kang Collection (Mr. and Mrs. Byung '
#                             'S. Kang) in honor of Robert D. Mowry',
#               'culture': 'Korean',
#               'datebegin': 0,
#               'dated': 'Proto Three Kingdoms period, 1st-2nd century',
#               'dateend': 200,
#               'dateoffirstpageview': '2009-08-11',
#               'dateoflastpageview': '2022-05-05',
#               'department': 'Department of Asian Art',
#               'description': None,
#               'dimensions': 'H. 28.8 x W. 23 x Diam. 21.2 cm (11 5/16 x 9 1/16 '
#                             'x 8 3/8 in.)',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 0,
#               'groupcount': 2,
#               'id': 200906,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:79130_dynmc',
#                           'copyright': None,
#                           'date': '2006-01-24',
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 18482790,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18482790',
#                           'imageid': 87553,
#                           'publiccaption': None,
#                           'renditionnumber': '79130',
#                           'technique': None,
#                           'width': 1913}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:30:46-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Proto-Kaya ware: grayish buff earthenware with '
#                         'appliqué handles and cord-marked surfaces',
#               'objectid': 200906,
#               'objectnumber': '1994.164',
#               'peoplecount': 0,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:79130_dynmc',
#               'provenance': 'Mr. and Mrs. Byung S. Kang, New York (by 1994), '
#                             'gift; to Harvard University Art Museums, 1994.',
#               'publicationcount': 0,
#               'rank': 1,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/200906',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'Round-Bottomed, Globular Jar with Flaring Lip and Two '
#                        'Pointed, Openwork Handles, and with Cord-Marked Decor',
#               'titlescount': 1,
#               'totalpageviews': 799,
#               'totaluniquepageviews': 712,
#               'url': 'https://www.harvardartmuseums.org/collections/object/200906',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'vessel', 'worktypeid': '403'}]},
#              {'accessionmethod': 'Gift',
#               'accessionyear': 2007,
#               'accesslevel': 1,
#               'century': '20th century',
#               'classification': 'Prints',
#               'classificationid': 23,
#               'colorcount': 10,
#               'colors': [{'color': '#af7d4b',
#                           'css3': '#cd853f',
#                           'hue': 'Yellow',
#                           'percent': 0.8060666666666667,
#                           'spectrum': '#e9715f'},
#                          {'color': '#af1900',
#                           'css3': '#b22222',
#                           'hue': 'Red',
#                           'percent': 0.12966666666666668,
#                           'spectrum': '#dd5872'},
#                          {'color': '#324b96',
#                           'css3': '#483d8b',
#                           'hue': 'Blue',
#                           'percent': 0.020733333333333333,
#                           'spectrum': '#4072b8'},
#                          {'color': '#af3219',
#                           'css3': '#b22222',
#                           'hue': 'Red',
#                           'percent': 0.013533333333333333,
#                           'spectrum': '#dd5872'},
#                          {'color': '#4b4b7d',
#                           'css3': '#483d8b',
#                           'hue': 'Violet',
#                           'percent': 0.008066666666666666,
#                           'spectrum': '#5e6db3'},
#                          {'color': '#af6432',
#                           'css3': '#a0522d',
#                           'hue': 'Orange',
#                           'percent': 0.0071333333333333335,
#                           'spectrum': '#e9715f'},
#                          {'color': '#644b64',
#                           'css3': '#696969',
#                           'hue': 'Violet',
#                           'percent': 0.005266666666666667,
#                           'spectrum': '#8362aa'},
#                          {'color': '#64647d',
#                           'css3': '#696969',
#                           'hue': 'Blue',
#                           'percent': 0.004533333333333334,
#                           'spectrum': '#7069af'},
#                          {'color': '#7d324b',
#                           'css3': '#a52a2a',
#                           'hue': 'Red',
#                           'percent': 0.0027333333333333333,
#                           'spectrum': '#b25593'},
#                          {'color': '#963232',
#                           'css3': '#a52a2a',
#                           'hue': 'Red',
#                           'percent': 0.0020666666666666667,
#                           'spectrum': '#d0577c'}],
#               'commentary': None,
#               'contact': 'am_moderncontemporary@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Vivian '
#                             'and Lionel Spiro',
#               'culture': 'American',
#               'datebegin': 1969,
#               'dated': '1969',
#               'dateend': 1969,
#               'dateoffirstpageview': '2009-05-25',
#               'dateoflastpageview': '2022-05-05',
#               'department': 'Department of Prints',
#               'description': None,
#               'dimensions': 'sheet: 76.1 x 50.7 cm (29 15/16 x 19 15/16 in.)',
#               'division': 'Modern and Contemporary Art',
#               'edition': None,
#               'exhibitioncount': 1,
#               'groupcount': 2,
#               'id': 318040,
#               'imagecount': 2,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104099_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2007-10-08',
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 20380053,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20380053',
#                           'imageid': 268978,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC104099',
#                           'technique': None,
#                           'width': 1699},
#                          {'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV141031_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2007-05-07',
#                           'description': None,
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 20305700,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20305700',
#                           'imageid': 234532,
#                           'publiccaption': None,
#                           'renditionnumber': 'INV141031',
#                           'technique': None,
#                           'width': 1725}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:33:56-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': None,
#               'objectid': 318040,
#               'objectnumber': '2007.8',
#               'people': [{'alphasort': 'Strike Poster Workshop',
#                           'birthplace': None,
#                           'culture': None,
#                           'deathplace': None,
#                           'displaydate': None,
#                           'displayname': 'Strike Poster Workshop',
#                           'displayorder': 1,
#                           'gender': 'unknown',
#                           'name': 'Strike Poster Workshop',
#                           'personid': 50996,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC104099_dynmc',
#               'provenance': None,
#               'publicationcount': 0,
#               'rank': 2,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/318040',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': 'Screen print',
#               'techniqueid': 306,
#               'title': 'Strike with Fist',
#               'titlescount': 1,
#               'totalpageviews': 1358,
#               'totaluniquepageviews': 1042,
#               'url': 'https://www.harvardartmuseums.org/collections/object/318040',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'print', 'worktypeid': '288'}]},
#              {'accessionmethod': 'Gift',
#               'accessionyear': 1978,
#               'accesslevel': 1,
#               'century': '18th century',
#               'classification': 'Drawings',
#               'classificationid': 21,
#               'colorcount': 6,
#               'colors': [{'color': '#e1af96',
#                           'css3': '#deb887',
#                           'hue': 'Orange',
#                           'percent': 0.2648587570621469,
#                           'spectrum': '#e9715f'},
#                          {'color': '#e1c8af',
#                           'css3': '#f5deb3',
#                           'hue': 'Orange',
#                           'percent': 0.2164406779661017,
#                           'spectrum': '#e9715f'},
#                          {'color': '#c8967d',
#                           'css3': '#bc8f8f',
#                           'hue': 'Grey',
#                           'percent': 0.20864406779661018,
#                           'spectrum': '#e66c64'},
#                          {'color': '#af7d64',
#                           'css3': '#cd5c5c',
#                           'hue': 'Brown',
#                           'percent': 0.18548022598870056,
#                           'spectrum': '#c85783'},
#                          {'color': '#96644b',
#                           'css3': '#a0522d',
#                           'hue': 'Brown',
#                           'percent': 0.08553672316384181,
#                           'spectrum': '#c25687'},
#                          {'color': '#fae1c8',
#                           'css3': '#ffe4c4',
#                           'hue': 'Yellow',
#                           'percent': 0.03903954802259887,
#                           'spectrum': '#ed765a'}],
#               'commentary': None,
#               'contact': 'am_europeanamerican@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Gift of Therese '
#                             'Kuhn Straus in memory of her husband, Herbert N. '
#                             'Straus, Harvard Class of 1903',
#               'culture': 'French',
#               'datebegin': 1759,
#               'dated': 'c. 1764',
#               'dateend': 1769,
#               'dateoffirstpageview': '2009-08-01',
#               'dateoflastpageview': '2022-05-06',
#               'department': 'Department of Drawings',
#               'description': None,
#               'dimensions': '29.2 x 37.2 cm (11 1/2 x 14 5/8 in.)',
#               'division': 'European and American Art',
#               'edition': None,
#               'exhibitioncount': 0,
#               'groupcount': 2,
#               'id': 295813,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': 'A scenic park landscape of old trees, '
#                                      'fountain, and small groups of people '
#                                      'gathered.',
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:61234_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2002-07-29',
#                           'description': 'The monochromatic drawing depicts a '
#                                          'group of women in long dresses, '
#                                          'bottom right of center. Two bend '
#                                          'over a wash basin, lifting garments, '
#                                          'the other two are standing and '
#                                          'talking, one pointing right, a boy '
#                                          'behind the other. A stone basin, '
#                                          'looking like a displaced fountain '
#                                          'section, rests to the right. A large '
#                                          'water fountain on left spews a tall '
#                                          'stream of water straight up, two '
#                                          'women gathered there, with backs '
#                                          'toward us. Pine or poplar trees '
#                                          'encircle half the fountain, an old '
#                                          'tree leans from the right. A wall '
#                                          'with steps and lion is faintly drawn '
#                                          'in the background.',
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2018,
#                           'idsid': 17388899,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17388899',
#                           'imageid': 54292,
#                           'publiccaption': None,
#                           'renditionnumber': '61234',
#                           'technique': None,
#                           'width': 2550}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:33:19-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 2,
#               'mediacount': 0,
#               'medium': 'Red chalk on cream antique laid paper, laid down on a '
#                         'decorated mount',
#               'objectid': 295813,
#               'objectnumber': '1978.51',
#               'people': [{'alphasort': 'Robert, Hubert',
#                           'birthplace': 'Paris',
#                           'culture': 'French',
#                           'deathplace': 'Paris',
#                           'displaydate': '1733 - 1808',
#                           'displayname': 'Hubert Robert',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'Hubert Robert',
#                           'personid': 28325,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:61234_dynmc',
#               'provenance': 'Therese Kuhn Straus, New York, gift; to Harvard '
#                             'Art Museums/Fogg Museum, Gift of Therese Kuhn '
#                             'Straus in memory of her husband, Herbert N. '
#                             'Straus, Harvard Class of 1903, 1978.51',
#               'publicationcount': 1,
#               'rank': 3,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/295813',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'Fountain in the Garden of an Italian Villa',
#               'titlescount': 2,
#               'totalpageviews': 836,
#               'totaluniquepageviews': 724,
#               'url': 'https://www.harvardartmuseums.org/collections/object/295813',
#               'verificationlevel': 4,
#               'verificationleveldescription': 'Best. Object is extensively '
#                                               'researched, well described and '
#                                               'information is vetted',
#               'worktypes': [{'worktype': 'drawing', 'worktypeid': '128'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 2002,
#               'accesslevel': 1,
#               'century': '2nd-3rd century CE',
#               'classification': 'Coins',
#               'classificationid': 50,
#               'colorcount': 6,
#               'colors': [{'color': '#afafaf',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.511264367816092,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#4b4b32',
#                           'css3': '#556b2f',
#                           'hue': 'Green',
#                           'percent': 0.19655172413793104,
#                           'spectrum': '#4ab851'},
#                          {'color': '#64644b',
#                           'css3': '#696969',
#                           'hue': 'Green',
#                           'percent': 0.11241379310344828,
#                           'spectrum': '#59ba4a'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.07114942528735632,
#                           'spectrum': '#8761aa'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.06609195402298851,
#                           'spectrum': '#2eb45d'},
#                          {'color': '#7d7d64',
#                           'css3': '#808080',
#                           'hue': 'Yellow',
#                           'percent': 0.04252873563218391,
#                           'spectrum': '#6cbd45'}],
#               'commentary': None,
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'David M. Robinson Fund',
#               'culture': 'Roman Provincial',
#               'datebegin': 197,
#               'dated': '197-217',
#               'dateend': 217,
#               'dateoffirstpageview': '2010-02-25',
#               'dateoflastpageview': '2022-05-06',
#               'department': 'Department of Ancient and Byzantine Art & '
#                             'Numismatics',
#               'description': 'Obv.: Bust of Caracalla, r., laureate and '
#                              'wearing paludamentum and cuirass.\r\n'
#                              'Rev.: Representation of the myth of Hero and '
#                              'Leander: Hero stands facing l. on tower '
#                              '(lighthouse of Sestos) at r., holding lighted '
#                              'lamp with extended r. arm and with l. hand on '
#                              'hip; Leander swims r.; above, Eros holding a '
#                              'torch flies r.',
#               'details': {'coins': {'dateonobject': None,
#                                     'denomination': None,
#                                     'dieaxis': '12',
#                                     'metal': 'AE',
#                                     'obverseinscription': None,
#                                     'reverseinscription': None}},
#               'dimensions': '31.37 g',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 0,
#               'groupcount': 2,
#               'id': 97575,
#               'imagecount': 4,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767471',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2018-05-21',
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 1001,
#                           'idsid': 450263076,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/450263076',
#                           'imageid': 489665,
#                           'publiccaption': None,
#                           'renditionnumber': '767471',
#                           'technique': 'Make:Hasselblad;Model:Hasselblad '
#                                        'H5D-50c '
#                                        'MS;Orientation:1;Software:Adobe '
#                                        'Photoshop CC 2018 (Macintosh);',
#                           'width': 2550},
#                          {'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:62504_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2003-08-28',
#                           'description': None,
#                           'displayorder': 2,
#                           'format': 'image/jpeg',
#                           'height': 954,
#                           'idsid': 17804986,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17804986',
#                           'imageid': 22041,
#                           'publiccaption': 'verso',
#                           'renditionnumber': '62504',
#                           'technique': None,
#                           'width': 1024},
#                          {'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:73751_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2003-07-22',
#                           'description': None,
#                           'displayorder': 3,
#                           'format': 'image/jpeg',
#                           'height': 918,
#                           'idsid': 17817337,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17817337',
#                           'imageid': 133832,
#                           'publiccaption': 'recto',
#                           'renditionnumber': '73751',
#                           'technique': None,
#                           'width': 1024},
#                          {'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:COIN15991_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2005-05-31',
#                           'description': None,
#                           'displayorder': 4,
#                           'format': 'image/jpeg',
#                           'height': 1188,
#                           'idsid': 3002852,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/3002852',
#                           'imageid': 45283,
#                           'publiccaption': None,
#                           'renditionnumber': 'COIN15991',
#                           'technique': None,
#                           'width': 2550}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:28:37-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Bronze',
#               'objectid': 97575,
#               'objectnumber': '2002.282.5',
#               'people': [{'alphasort': 'Caracalla',
#                           'birthplace': None,
#                           'culture': 'Roman',
#                           'deathplace': None,
#                           'displaydate': 'r. 188 - 217 CE',
#                           'displayname': 'Caracalla',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'Caracalla',
#                           'personid': 19588,
#                           'prefix': None,
#                           'role': 'Coin Constituent'}],
#               'peoplecount': 1,
#               'period': 'Roman Imperial period, Middle',
#               'periodid': 632,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767471',
#               'provenance': 'Th. Prowe and V.M. Brand Coll.\r\n'
#                             'Auktion Egger, Vienna 46 (1914) lot.603\r\n'
#                             'Sotheby Parke Bernett, London, The Brand '
#                             'Collection 7 (1984) lot.359\r\n'
#                             'M&M Deutschland, Auktion 11, 7-8 November 2002, '
#                             'lot.62',
#               'publicationcount': 0,
#               'rank': 4,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/97575',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': 'Cf. BMC p. 7 no. 60 (rev.)',
#               'state': None,
#               'style': None,
#               'technique': 'Struck',
#               'techniqueid': 7320,
#               'title': 'Coin of Abydos under Caracalla',
#               'titlescount': 1,
#               'totalpageviews': 848,
#               'totaluniquepageviews': 726,
#               'url': 'https://www.harvardartmuseums.org/collections/object/97575',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'coin', 'worktypeid': '103'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 1990,
#               'accesslevel': 1,
#               'century': '18th century',
#               'classification': 'Drawings',
#               'classificationid': 21,
#               'colorcount': 9,
#               'colors': [{'color': '#c8af7d',
#                           'css3': '#d2b48c',
#                           'hue': 'Brown',
#                           'percent': 0.24403508771929824,
#                           'spectrum': '#e9715f'},
#                          {'color': '#e1c896',
#                           'css3': '#deb887',
#                           'hue': 'Yellow',
#                           'percent': 0.2088888888888889,
#                           'spectrum': '#ed765a'},
#                          {'color': '#af9664',
#                           'css3': '#bdb76b',
#                           'hue': 'Yellow',
#                           'percent': 0.16286549707602338,
#                           'spectrum': '#e9715f'},
#                          {'color': '#fae1af',
#                           'css3': '#ffdead',
#                           'hue': 'Yellow',
#                           'percent': 0.16140350877192983,
#                           'spectrum': '#ef7a55'},
#                          {'color': '#96644b',
#                           'css3': '#a0522d',
#                           'hue': 'Brown',
#                           'percent': 0.12070175438596491,
#                           'spectrum': '#c25687'},
#                          {'color': '#7d4b32',
#                           'css3': '#8b4513',
#                           'hue': 'Brown',
#                           'percent': 0.06251461988304094,
#                           'spectrum': '#c25687'},
#                          {'color': '#4b3219',
#                           'css3': '#556b2f',
#                           'hue': 'Brown',
#                           'percent': 0.02976608187134503,
#                           'spectrum': '#4ab851'},
#                          {'color': '#321919',
#                           'css3': '#000000',
#                           'hue': 'Brown',
#                           'percent': 0.009707602339181286,
#                           'spectrum': '#3db657'},
#                          {'color': '#190000',
#                           'css3': '#000000',
#                           'hue': 'Black',
#                           'percent': 0.00011695906432748539,
#                           'spectrum': '#2eb45d'}],
#               'commentary': None,
#               'contact': 'am_europeanamerican@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Fogg Museum, Alvin Whitley '
#                             'Fund',
#               'culture': 'British',
#               'datebegin': 1776,
#               'dated': '1776',
#               'dateend': 1776,
#               'dateoffirstpageview': '2009-06-23',
#               'dateoflastpageview': '2022-05-06',
#               'department': 'Department of Drawings',
#               'description': None,
#               'dimensions': '27.8 x 20.7 cm (10 15/16 x 8 1/8 in.)',
#               'division': 'European and American Art',
#               'edition': None,
#               'exhibitioncount': 6,
#               'groupcount': 1,
#               'id': 294419,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS46453_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': None,
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 20681311,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20681311',
#                           'imageid': 33233,
#                           'publiccaption': None,
#                           'renditionnumber': '46453',
#                           'technique': 'Kodak EPY',
#                           'width': 1943}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:33:17-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Black ink on off-white antique laid paper',
#               'objectid': 294419,
#               'objectnumber': '1990.56',
#               'people': [{'alphasort': 'Mortimer, John Hamilton',
#                           'birthplace': 'Eastbourne, England',
#                           'culture': 'British',
#                           'deathplace': 'London',
#                           'displaydate': '1740 - 1779',
#                           'displayname': 'John Hamilton Mortimer',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'John Hamilton Mortimer',
#                           'personid': 27702,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS46453_dynmc',
#               'provenance': 'Sir George Beaumont. Sir John and Lady Witt, sale '
#                             "[Sotheby's, London, February 19, 1987, lot 46; "
#                             'Lugt 646a]. [W.M. Brady & Co., New York] sold; to '
#                             'Harvard University Art Museums, 1990',
#               'publicationcount': 11,
#               'rank': 5,
#               'relatedcount': 1,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/294419',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': 'black ink, on book: JH Mortimer/1776',
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'Salvator Rosa',
#               'titlescount': 1,
#               'totalpageviews': 891,
#               'totaluniquepageviews': 775,
#               'url': 'https://www.harvardartmuseums.org/collections/object/294419',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'drawing', 'worktypeid': '128'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 1973,
#               'accesslevel': 1,
#               'century': '20th century',
#               'classification': 'Photographs',
#               'classificationid': 17,
#               'colorcount': 10,
#               'colors': [{'color': '#c8c8c8',
#                           'css3': '#c0c0c0',
#                           'hue': 'Grey',
#                           'percent': 0.22972972972972974,
#                           'spectrum': '#8c5fa8'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.19135135135135134,
#                           'spectrum': '#2eb45d'},
#                          {'color': '#191919',
#                           'css3': '#000000',
#                           'hue': 'Grey',
#                           'percent': 0.1790990990990991,
#                           'spectrum': '#1eb264'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.11117117117117117,
#                           'spectrum': '#3db657'},
#                          {'color': '#646464',
#                           'css3': '#696969',
#                           'hue': 'Grey',
#                           'percent': 0.08768768768768768,
#                           'spectrum': '#7866ad'},
#                          {'color': '#7d7d7d',
#                           'css3': '#808080',
#                           'hue': 'Grey',
#                           'percent': 0.07423423423423424,
#                           'spectrum': '#8362aa'},
#                          {'color': '#af967d',
#                           'css3': '#bc8f8f',
#                           'hue': 'Brown',
#                           'percent': 0.041561561561561565,
#                           'spectrum': '#c25687'},
#                          {'color': '#c8af96',
#                           'css3': '#d2b48c',
#                           'hue': 'Brown',
#                           'percent': 0.03087087087087087,
#                           'spectrum': '#e66c64'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.024624624624624624,
#                           'spectrum': '#8761aa'},
#                          {'color': '#afafaf',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.018858858858858858,
#                           'spectrum': '#8c5fa8'}],
#               'commentary': None,
#               'contact': 'am_moderncontemporary@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': '© The Robert Heinecken Trust and Pace MacGill '
#                            'Gallery',
#               'creditline': 'Harvard Art Museums/Fogg Museum, National '
#                             'Endowment for the Arts Grant',
#               'culture': 'American',
#               'datebegin': 1973,
#               'dated': '1973',
#               'dateend': 1973,
#               'dateoffirstpageview': '2009-08-14',
#               'dateoflastpageview': '2022-05-06',
#               'department': 'Department of Photographs',
#               'description': None,
#               'dimensions': 'actual: 25 x 33 x 4 cm (9 13/16 x 13 x 1 9/16 '
#                             'in.)',
#               'division': 'Modern and Contemporary Art',
#               'edition': None,
#               'exhibitioncount': 4,
#               'groupcount': 1,
#               'id': 303395,
#               'imagecount': 1,
#               'imagepermissionlevel': 1,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG1044_dynmc_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': None,
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 758,
#                           'idsid': 43155041,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/43155041',
#                           'imageid': 94366,
#                           'publiccaption': None,
#                           'renditionnumber': 'LEG1044',
#                           'technique': None,
#                           'width': 1024}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:33:32-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': None,
#               'objectid': 303395,
#               'objectnumber': 'P1973.67',
#               'people': [{'alphasort': 'Heinecken, Robert',
#                           'birthplace': 'Denver, Colorado',
#                           'culture': 'American',
#                           'deathplace': 'Albuquerque, New Mexico',
#                           'displaydate': '1931 - 2006',
#                           'displayname': 'Robert Heinecken',
#                           'displayorder': 1,
#                           'gender': 'male',
#                           'name': 'Robert Heinecken',
#                           'personid': 34609,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG1044_dynmc_dynmc',
#               'provenance': 'Robert Heinecken, Los Angeles, California, sold '
#                             'to the Fogg Art Museum, 1973.\r\n',
#               'publicationcount': 2,
#               'rank': 6,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/303395',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': 'Photoscreenprint',
#               'techniqueid': 1931,
#               'title': 'TV Dinner Before/After',
#               'titlescount': 1,
#               'totalpageviews': 923,
#               'totaluniquepageviews': 778,
#               'url': 'https://www.harvardartmuseums.org/collections/object/303395',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'photograph', 'worktypeid': '269'}]},
#              {'accessionmethod': 'Gift',
#               'accessionyear': 1933,
#               'accesslevel': 1,
#               'century': '19th century',
#               'classification': 'Prints',
#               'classificationid': 23,
#               'colorcount': 7,
#               'colors': [{'color': '#64644b',
#                           'css3': '#696969',
#                           'hue': 'Green',
#                           'percent': 0.30182291666666666,
#                           'spectrum': '#59ba4a'},
#                          {'color': '#7d7d64',
#                           'css3': '#808080',
#                           'hue': 'Yellow',
#                           'percent': 0.22005208333333334,
#                           'spectrum': '#6cbd45'},
#                          {'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.17317708333333334,
#                           'spectrum': '#3db657'},
#                          {'color': '#96967d',
#                           'css3': '#808080',
#                           'hue': 'Green',
#                           'percent': 0.14895833333333333,
#                           'spectrum': '#8e5ea7'},
#                          {'color': '#afaf96',
#                           'css3': '#a9a9a9',
#                           'hue': 'Green',
#                           'percent': 0.13546875,
#                           'spectrum': '#8e5ea7'},
#                          {'color': '#c8afaf',
#                           'css3': '#c0c0c0',
#                           'hue': 'Red',
#                           'percent': 0.015572916666666667,
#                           'spectrum': '#b55592'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.0049479166666666664,
#                           'spectrum': '#2eb45d'}],
#               'commentary': None,
#               'contact': 'am_asianmediterranean@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': None,
#               'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, '
#                             'Gift of the Friends of Arthur B. Duel',
#               'culture': 'Japanese',
#               'datebegin': 1832,
#               'dated': 'Edo period, probably 1832',
#               'dateend': 1832,
#               'dateoffirstpageview': '2009-06-30',
#               'dateoflastpageview': '2022-05-06',
#               'department': 'Department of Asian Art',
#               'description': None,
#               'dimensions': 'Paper: H. 21.1 cm x W. 18.2 cm (8 5/16 x 7 3/16 '
#                             'in.)',
#               'division': 'Asian and Mediterranean Art',
#               'edition': None,
#               'exhibitioncount': 0,
#               'groupcount': 2,
#               'id': 207541,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:DDC105003_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2008-02-04',
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 2550,
#                           'idsid': 8238511,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/8238511',
#                           'imageid': 289040,
#                           'publiccaption': None,
#                           'renditionnumber': 'DDC105003',
#                           'technique': None,
#                           'width': 2192}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:30:57-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Ukiyo-e woodblock-printed "surimono" in "shikishiban" '
#                         'format; Ink, color and metallic pigment on paper',
#               'objectid': 207541,
#               'objectnumber': '1933.4.1856',
#               'people': [{'alphasort': 'Totoya, Hokkei',
#                           'birthplace': None,
#                           'culture': 'Japanese',
#                           'deathplace': None,
#                           'displaydate': '1780-1850',
#                           'displayname': 'Totoya Hokkei 魚屋北渓',
# ...
#                           'width': 548},
#                          {'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS48570_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': None,
#                           'description': None,
#                           'displayorder': 9,
#                           'format': 'image/jpeg',
#                           'height': 1024,
#                           'idsid': 20682211,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/20682211',
#                           'imageid': 41406,
#                           'publiccaption': None,
#                           'renditionnumber': '48570',
#                           'technique': 'Super XX',
#                           'width': 845},
#                          {'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:74343_dynmc',
#                           'copyright': 'President and Fellows of Harvard '
#                                        'College',
#                           'date': '2003-10-07',
#                           'description': None,
#                           'displayorder': 10,
#                           'format': 'image/jpeg',
#                           'height': 1024,
#                           'idsid': 17817709,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17817709',
#                           'imageid': 133929,
#                           'publiccaption': 'back',
#                           'renditionnumber': '74343',
#                           'technique': None,
#                           'width': 610}],
#               'labeltext': 'Buddhist proselytizers from northern China and '
#                            'Central Asia first entered the Korean peninsula in '
#                            'the final decades of the fourth century. In the '
#                            'centuries that followed, Korean Buddhists '
#                            'developed their own traditions of ritual practice '
#                            'and systems of philosophical thought, but they '
#                            'were also in constant dialogue with their monastic '
#                            'counterparts in China, exchanging both texts and '
#                            'images. Icons were frequently presented as gifts '
#                            'among the rulers, merchants, and monks of China, '
#                            'Korea, and Japan, which led to a high degree of '
#                            'stylistic cross-pollination across the three '
#                            'cultures. Private, portable icons like these gilt '
#                            'bronze images—which, though crafted in Korea, '
#                            'share many visual traits with similar objects from '
#                            'China and Japan—provided an ideal medium for '
#                            'intercultural artistic and religious exchange. '
#                            'Such images are likely to have been worshipped on '
#                            'small altars in domestic settings. The portable '
#                            'shrine displayed here, from the Chosŏn dynasty '
#                            '(1392–1910), helps us to imagine the original '
#                            'display contexts for the images that surround it. '
#                            'A mobile, self-contained setting for icon worship, '
#                            'it differs little in form, material, or concept '
#                            'from the portable shrines that devotees first '
#                            'brought from India to Central Asia and China '
#                            'centuries before.',
#               'lastupdate': '2022-05-16T05:30:52-0400',
#               'lendingpermissionlevel': 2,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'Gilt bronze',
#               'objectid': 204439,
#               'objectnumber': '1943.53.75',
#               'peoplecount': 0,
#               'period': 'Three Kingdoms period, Paekche, 18 BCE-660 CE',
#               'periodid': 3675,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:74342_dynmc',
#               'provenance': 'Grenville L. Winthrop (1864-1943), New York (by '
#                             '1943), bequest; to Fogg Art Museum, 1943.',
#               'publicationcount': 1,
#               'rank': 9,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/204439',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': None,
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'Crowned Bodhisattva, Probably Taeseji Posal '
#                        '(Bodhisattva Mahasthamaprapta), Standing on a '
#                        "Heptagonal, Double-Lotus Base, the Bodhisattva's Right "
#                        'Hand Raised, the Left Hand Lowered',
#               'titlescount': 2,
#               'totalpageviews': 937,
#               'totaluniquepageviews': 810,
#               'url': 'https://www.harvardartmuseums.org/collections/object/204439',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'figurine', 'worktypeid': '142'},
#                             {'worktype': 'sculpture', 'worktypeid': '330'}]},
#              {'accessionmethod': 'Purchase',
#               'accessionyear': 2009,
#               'accesslevel': 1,
#               'century': '21st century',
#               'classification': 'Paintings',
#               'classificationid': 26,
#               'colorcount': 10,
#               'colors': [{'color': '#4b4b4b',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.1745736434108527,
#                           'spectrum': '#3db657'},
#                          {'color': '#969696',
#                           'css3': '#a9a9a9',
#                           'hue': 'Grey',
#                           'percent': 0.1737984496124031,
#                           'spectrum': '#8761aa'},
#                          {'color': '#323232',
#                           'css3': '#2f4f4f',
#                           'hue': 'Grey',
#                           'percent': 0.1702842377260982,
#                           'spectrum': '#2eb45d'},
#                          {'color': '#963219',
#                           'css3': '#8b4513',
#                           'hue': 'Brown',
#                           'percent': 0.14873385012919896,
#                           'spectrum': '#d75776'},
#                          {'color': '#969664',
#                           'css3': '#808080',
#                           'hue': 'Green',
#                           'percent': 0.057829457364341086,
#                           'spectrum': '#84c441'},
#                          {'color': '#646464',
#                           'css3': '#696969',
#                           'hue': 'Grey',
#                           'percent': 0.053229974160206715,
#                           'spectrum': '#7866ad'},
#                          {'color': '#194b7d',
#                           'css3': '#483d8b',
#                           'hue': 'Blue',
#                           'percent': 0.031421188630490954,
#                           'spectrum': '#2474ba'},
#                          {'color': '#004b7d',
#                           'css3': '#008080',
#                           'hue': 'Blue',
#                           'percent': 0.026976744186046512,
#                           'spectrum': '#1175bc'},
#                          {'color': '#af7d4b',
#                           'css3': '#cd853f',
#                           'hue': 'Yellow',
#                           'percent': 0.026098191214470285,
#                           'spectrum': '#e9715f'},
#                          {'color': '#009696',
#                           'css3': '#008b8b',
#                           'hue': 'Green',
#                           'percent': 0.023152454780361757,
#                           'spectrum': '#009999'}],
#               'commentary': 'Amy Sillman\'s "L" is from a body of work first '
#                             'exhibited at the Hirschhorn museum under the '
#                             'collective title "Third Person Singular."  The '
#                             'works all began as part of a drawing project '
#                             'Sillman established for herself to draw portraits '
#                             'of couples she knew.  Using intimate friends as '
#                             'life models Sillman would both draw the couples '
#                             '"as is" as well as arrange them into various '
#                             'poses.  After this encounter she would return to '
#                             'the studio and then draw the couple from memory. '
#                             'Drawings would then proceed from the "memory '
#                             'drawing" until such a point that the drawing '
#                             'itself was almost, if not completely, abstract. '
#                             'These drawings ultimately became the basis for a '
#                             'series of abstract paintings-though there is no '
#                             'strong one-to-one correlation between individual '
#                             'drawings and paintings-rather what Sillman did '
#                             'was establish a set of rules and coordinates for '
#                             'making an abstract painting.  Hence the paintings '
#                             'themselves show no trace of their conception.  '
#                             'Rather they appear to be completely abstract, and '
#                             'their push-pull fields of color recall the '
#                             'gestural exploration of abstract '
#                             'expressionism-particularly the planes of Richard '
#                             'Diebenkorn and the palette of Willem DeKooning. '
#                             "Philip Guston's exploration of abstraction and "
#                             'political horror is another important touch stone '
#                             "for Sillman.  Sillman's earlier cartoonish style "
#                             'had a decidedly neurotic quality-pictures of '
#                             'small figures facing insurmountable odds.  In '
#                             'this series the emotional affect of awkwardness '
#                             'has been submerged into plays of color and '
#                             'abutting planes.  The paintings feel a bit like a '
#                             'dare or a question about whether or not its '
#                             'possible to make a meaningful abstract painting '
#                             'in the early years of 2000.  Can abstract escape '
#                             'the yoke of abstract expressionism? Can we talk '
#                             'about affect when there is no ostensible subject '
#                             'matter? Is there a legible grammar of painting?  '
#                             'Is there a politics and poetics of color and '
#                             'contemporary painting?  These are just a few of '
#                             "the questions Sillman's paintings pose.\r\n",
#               'contact': 'am_moderncontemporary@harvard.edu',
#               'contextualtextcount': 0,
#               'copyright': '© Amy Sillman',
#               'creditline': 'Harvard Art Museums/Fogg Museum, The Jorie '
#                             "Marshall Waterman '96 and Gwendolyn Dunaway "
#                             "Waterman '92 Fund",
#               'culture': 'American',
#               'datebegin': 2007,
#               'dated': '2007',
#               'dateend': 2007,
#               'dateoffirstpageview': '2009-08-19',
#               'dateoflastpageview': '2022-05-06',
#               'department': 'Department of Modern & Contemporary Art',
#               'description': None,
#               'dimensions': '114.3 x 99.1 cm (45 x 39 in.)',
#               'division': 'Modern and Contemporary Art',
#               'edition': None,
#               'exhibitioncount': 1,
#               'groupcount': 1,
#               'id': 331542,
#               'imagecount': 1,
#               'imagepermissionlevel': 0,
#               'images': [{'alttext': None,
#                           'baseimageurl': 'https://nrs.harvard.edu/urn-3:huam:LEG004895_dynmc',
#                           'copyright': None,
#                           'date': '2009-04-14',
#                           'description': None,
#                           'displayorder': 1,
#                           'format': 'image/jpeg',
#                           'height': 275,
#                           'idsid': 12781264,
#                           'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/12781264',
#                           'imageid': 340334,
#                           'publiccaption': None,
#                           'renditionnumber': 'LEG004895',
#                           'technique': None,
#                           'width': 238}],
#               'labeltext': None,
#               'lastupdate': '2022-05-16T05:34:15-0400',
#               'lendingpermissionlevel': 0,
#               'markscount': 0,
#               'mediacount': 0,
#               'medium': 'oil on canvas',
#               'objectid': 331542,
#               'objectnumber': '2009.51',
#               'people': [{'alphasort': 'Sillman, Amy',
#                           'birthplace': 'Detroit, Michigan',
#                           'culture': 'American',
#                           'deathplace': None,
#                           'displaydate': 'born 1956',
#                           'displayname': 'Amy Sillman',
#                           'displayorder': 1,
#                           'gender': 'unknown',
#                           'name': 'Amy Sillman',
#                           'personid': 54372,
#                           'prefix': None,
#                           'role': 'Artist'}],
#               'peoplecount': 1,
#               'period': None,
#               'periodid': None,
#               'primaryimageurl': 'https://nrs.harvard.edu/urn-3:huam:LEG004895_dynmc',
#               'provenance': '[Sikkema Jenkins & Co.] sold; to Harvard Art '
#                             'Museum, March 2009.',
#               'publicationcount': 1,
#               'rank': 10,
#               'relatedcount': 0,
#               'seeAlso': [{'format': 'application/json',
#                            'id': 'https://iiif.harvardartmuseums.org/manifests/object/331542',
#                            'profile': 'http://iiif.io/api/presentation/2/context.json',
#                            'type': 'IIIF Manifest'}],
#               'signed': 'signed on verso',
#               'standardreferencenumber': None,
#               'state': None,
#               'style': None,
#               'technique': None,
#               'techniqueid': None,
#               'title': 'L',
#               'titlescount': 1,
#               'totalpageviews': 1055,
#               'totaluniquepageviews': 912,
#               'url': 'https://www.harvardartmuseums.org/collections/object/331542',
#               'verificationlevel': 3,
#               'verificationleveldescription': 'Good. Object is well described '
#                                               'and information is vetted',
#               'worktypes': [{'worktype': 'painting', 'worktypeid': '251'}]}]}

# %% [markdown]
# That's it. Really, we are done here. Everyone go home!
#
# OK not really, there is still more we can learn. But you have to admit
# that was pretty easy. If you can identify a service that returns the
# data you want in structured from, web scraping becomes a pretty
# trivial enterprise. We'll discuss several other scenarios and topics,
# but for some web scraping tasks this is really all you need to know.
#
# ### Organizing & saving the data
#
# The records we retrieved from
# `https://www.harvardartmuseums.org/browse` are arranged as a list of
# dictionaries. We can easily select the fields of arrange these data
# into a pandas `DataFrame` to facilitate subsequent analysis.

# %%
# a field in the JSON by the name of 'records'

import pandas as pd

# %%
records_df = pd.DataFrame(r.json()['records'])

# %%
print(records_df)
# Out:
#                        copyright  contextualtextcount  ...                         people                        details
# 0                           None                    0  ...                            NaN                            NaN
# 1                           None                    0  ...  [{'role': 'Artist', 'birth...                            NaN
# 2                           None                    0  ...  [{'role': 'Artist', 'birth...                            NaN
# 3                           None                    0  ...  [{'role': 'Coin Constituen...  {'coins': {'reverseinscrip...
# 4                           None                    0  ...  [{'role': 'Artist', 'birth...                            NaN
# 5  © The Robert Heinecken Tru...                    0  ...  [{'role': 'Artist', 'birth...                            NaN
# 6                           None                    0  ...  [{'role': 'Artist', 'birth...                            NaN
# 7                           None                    0  ...  [{'role': 'Artist', 'birth...                            NaN
# 8                           None                    0  ...                            NaN                            NaN
# 9                  © Amy Sillman                    0  ...  [{'role': 'Artist', 'birth...                            NaN
#
# [10 rows x 63 columns]

# %% [markdown]
# and write the data to a file.

# %%
records_df.to_csv('harvard_records_csv.csv')

# %% [markdown]
# ### Iterating to retrieve all the data
#
# Of course we don't want just the first page of collections. How can we
# retrieve all of them?
#
# Now that we know the web service works, and how to make requests in
# Python, we can iterate in the usual way.

# %%
records = []

for offset in range(0, 50, 10):
    # 0 to 50, increment by 10 due to load_amount
    param_values = {'load_amount': 10, 'offset': offset}
    current_request = requests.get(collection_url, params = param_values)
    # help(records.extend)
    # The extend() method adds all the elements of an iterable (list, tuple, string etc.) to the end of the list.
    records.extend(current_request.json()['records'])

# %%
## convert list of dicts to a `DataFrame`

records_50_df = pd.DataFrame(records)

# %%
# write the data to a file.
records_50_df.to_csv('records_50_csv.csv')

# %% [markdown]
# ### Exercise 0
#
# **Retrieve exhibits data**
#
# In this exercise you will retrieve information about the art
# exhibitions at Harvard Art Museums from
# `https://www.harvardartmuseums.org/visit/exhibitions`
#
# 1. Using a web browser (Firefox or Chrome recommended) inspect the
#    page at `https://www.harvardartmuseums.org/visit/exhibitions`. Examine
#    the network traffic as you interact with the page. Try to find
#    where the data displayed on that page comes from.

# %%
exhibits_domain = 'https://harvardartmuseums.org'

exhibits_path = 'search/load_more'

exhibits_params = {'type': 'past-exhibition', 'year': '', 'page': 1, '_': 1652736051676}

exhibits_url = (exhibits_domain
               +
               '/'
               +
               exhibits_path)

print(exhibits_url)
# Out:
# 'https://harvardartmuseums.org/search/load_more'

# %% [markdown]
# 2. Make a `get` request in Python to retrieve the data from the URL
#    identified in step1.

# %%
requests.get(exhibits_url, exhibits_params).json()
# Out:
# {'info': {'totalrecordsperquery': 10,
#   'totalrecords': 565,
#   'pages': 57,
#   'page': 2,
#   'next': 'https://api.harvardartmuseums.org/exhibition?apikey=67d9edc0-e6a3-11e3-9798-57275476509a&sort=chronological&sortorder=desc&from=10&size=10&status=past&venue=HAM&before=enddate%3A2022-05-16&page=3',
#   'prev': 'https://api.harvardartmuseums.org/exhibition?apikey=67d9edc0-e6a3-11e3-9798-57275476509a&sort=chronological&sortorder=desc&from=10&size=10&status=past&venue=HAM&before=enddate%3A2022-05-16&page=1'},
#  'records': [{'shortdescription': None,
#    'images': [{'date': '2019-03-18',
#      'copyright': 'Image copyright © The Metropolitn Museum of Art. Image source: Art Resource, NY',
#      'imageid': 495715,
#      'idsid': 462607066,
#      'format': 'image/jpeg',
#      'caption': 'Winslow Homer, Prisoners from the Front, 1866. Oil on canvas. The Metropolitan Museum of Art, New York, Gift of Mrs. Frank B. Porter, 1922, 22.207, TL42108. Photo: © The Metropolitan Museum of Art. Image source: Art Resource, NY.',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'LEG270275',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270275',
#      'alttext': None,
#      'width': 2550,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/462607066',
#      'height': 1606}],
#    'begindate': '2019-08-31',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5660,
#    'title': 'Winslow Homer: Eyewitness',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270275',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Ethan Lasser',
#      'name': 'Ethan Lasser',
#      'personid': 58267,
#      'displayorder': 1},
#     {'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Makeda Best',
#      'name': 'Makeda Best',
#      'personid': 63840,
#      'displayorder': 2}],
#    'temporalorder': 4728,
#    'url': 'https://harvardartmuseums.org/exhibitions/5660/winslow-homer-eyewitness',
#    'textiledescription': 'Discover how celebrated American artist Winslow Homer’s work for the illustrated periodical _Harper’s Weekly_ helped shape his later career as a painter and watercolorist.\r\n\r\nDuring the Civil War (1861–1865), American artist Winslow Homer (1836–1910) served as a correspondent for _Harper’s_. His sketches of soldiers, both in battle on the front lines and in quieter moments back at camp, were reproduced to accompany the journal’s accounts of the conflict. Homer worked for _Harper’s_ just as new technologies were making it possible to rapidly reproduce newsworthy images on a large scale. Working together with _Harper’s_ editors and engravers, he employed a range of pictorial strategies to reassure skeptical readers that his illustrations were not fabrications, but eyewitness observations “drawn on the spot.”\r\n\r\nWhile in the field as an artist-correspondent, Homer developed habits of seeing and pictorial strategies that informed his work in other media. In addition to tracing these connections, this show explores broader questions that Homer’s art raises about the responsibility of artists who work in periods riven by war and conflict.\r\n\r\nCo-curated by Ethan W. Lasser, Theodore E. Stebbins Jr. Curator of American Art and Head of the Division of European and American Art; and Makeda Best, Richard L. Menschel Curator of Photography; with the assistance of Oliver Wunsch, former Maher Curatorial Fellow of American Art (2018–19), Harvard Art Museums.\r\n\r\nSupport for this exhibition was provided by the Bolton Fund for American Art, Gift of the Payne Fund; and the Henry Luce Foundation Fund for the American Art Department. Exhibition-related programming is made possible by the Richard L. Menschel Endowment Fund and the M. Victor Leventritt Lecture Series Endowment Fund.\r\n\r\n*Related Exhibition*\r\n"_Homer at the Beach: A Marine Painter\'s Journey, 1869-1880_":https://www.capeannmuseum.org/exhibitions/homer-beach/ is on view at the Cape Ann Museum August 3–December 1, 2019.',
#    'enddate': '2020-01-05',
#    'venues': [{'country': None,
#      'begindate': '2019-08-31',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2020-01-05',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3600',
#        'galleryid': 3600,
#        'name': 'University Research Gallery',
#        'floor': 3}]}],
#    'id': 5660,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270275',
#     'caption': 'Winslow Homer, Prisoners from the Front, 1866. Oil on canvas. The Metropolitan Museum of Art, New York, Gift of Mrs. Frank B. Porter, 1922, 22.207, TL42108. Photo: © The Metropolitan Museum of Art. Image source: Art Resource, NY.'}},
#   {'shortdescription': None,
#    'images': [{'date': '2018-05-30',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 487896,
#      'idsid': 444994193,
#      'format': 'image/jpeg',
#      'caption': 'Utagawa Hiroshige, Japanese, Bow-Shaped Crescent Moon, from the series Twenty-Eight Views of the Moon, Edo period, c. 1832. Woodblock print; ink and color on paper. Harvard Art Museums/Arthur M. Sackler Museum, Gift of the Friends of Arthur B. Duel, 1933.4.323.',
#      'description': 'At the top are several lines of Japanese script and three red stamps  There is  a line of Japanese script and red seal at the bottom and  also a red banner with script along the left.  The left side is dominated by a grey cliff, with greenery growing on it.  A high woven bridge  stretches to another mountain peak on the right which consists of tall trees on a red crag.  Below this is grey mountainside and a waterfall.  A white crescent moon can be seen against the deep blue space between the mountains.  ',
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '767137',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767137',
#      'alttext': 'A mountainous landscape an either side with trees. Deep blue at the top and in the center with a white crescent.',
#      'width': 1175,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/444994193',
#      'height': 2550}],
#    'begindate': '2019-05-25',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5803,
#    'title': 'Japan on Paper',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767137',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Rachel Saunders',
#      'name': 'Rachel Saunders',
#      'personid': 62111,
#      'displayorder': 1},
#     {'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Quintana Heathman',
#      'name': 'Quintana Heathman',
#      'personid': 60713,
#      'displayorder': 2}],
#    'temporalorder': 4718,
#    'url': 'https://harvardartmuseums.org/exhibitions/5803/japan-on-paper',
#    'textiledescription': 'Japanese woodblock prints, with their sophisticated designs and bold planes of color, have long attracted viewers and inspired Western artists such as Vincent van Gogh and Mary Cassatt. These technically refined and aesthetically exciting prints were among the earliest works of Asian art acquired by the Harvard Art Museums, first entering the collections in 1910. Today the museums house approximately 5,000 single-sheet Japanese woodblock prints, and this exhibition introduces a selection of superlative impressions from this lively medium. The exhibition also seeks to highlight the individuals whose generosity has made it possible for generations of Harvard students to encounter and learn from these works.\r\n\r\nThe exhibition features almost 50 works spanning the history of Japanese woodblock printing, from the 17th through 20th century; these include single-sheet prints, luxury _surimono_ prints, printed handscrolls, and printed books by renowned designers such as Suzuki Harunobu (1725–1770), pioneer of the full-color print; landscape specialist Utagawa Hiroshige (1797–1858); enigmatic designer Sharaku (active 1794–95), best known for “big head” (_ōkubi_) actor prints; Itō Jakuchū (1716–1800); and the ever-popular Katsushika Hokusai (1760–1849). Also included are modern “new print” (_shin hanga_) and “creative print” (_sōsaku hanga_) works by the leaders of these two 20th-century movements, as well as a selection of woodblock printing tools to enhance visitors’ understanding of the medium.\r\n\r\nThe exhibition also marks the first public presentation of the museums’ newest acquisition in the area of Japanese prints, a contemporary work by Noriko Saitō (b. 1973).\r\n\r\nCurated by Quintana Heathman, former Curatorial Fellow in Japanese Art (2014–16); and Rachel Saunders, Abby Aldrich Rockefeller Associate Curator of Asian Art, Harvard Art Museums.\r\n\r\nSupport for this exhibition was provided by Harvard University’s Edwin O. Reischauer Institute of Japanese Studies and by the Harvard Art Museums’ Leopold (Harvard M.B.A. ’64) and Jane Swergold Asian Art Exhibitions and Publications Fund, Peter Drucker Research and Exhibition Fund, and José Soriano Fund.',
#    'enddate': '2019-08-11',
#    'venues': [{'country': None,
#      'begindate': '2019-05-25',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-08-11',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3620',
#        'galleryid': 3620,
#        'name': 'University Study Gallery',
#        'floor': 3}]}],
#    'id': 5803,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:767137',
#     'caption': 'Utagawa Hiroshige, Japanese, Bow-Shaped Crescent Moon, from the series Twenty-Eight Views of the Moon, Edo period, c. 1832. Woodblock print; ink and color on paper. Harvard Art Museums/Arthur M. Sackler Museum, Gift of the Friends of Arthur B. Duel, 1933.4.323.'}},
#   {'shortdescription': None,
#    'images': [{'date': '2018-08-29',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 491287,
#      'idsid': 457648678,
#      'format': 'image/jpeg',
#      'caption': 'Prince Shōtoku at Age Two, Japanese, Kamakura period, datable to c. 1292. Wood (hinoki cypress) with polychromy; inlaid rock crystal (quartz) eyes. Harvard Art Museums/Arthur M. Sackler Museum, Partial and promised gift of Walter C. Sedgwick in memory of Ellery Sedgwick Sr. and Ellery Sedgwick Jr., 2019.122.',
#      'description': 'The wooden sculpture is of a young boy standing upright and facing the viewer. He is wearing a red piece of clothing that goes from his hips and covers his feet. His hands are together and in front of his chest. His face is very round with round red lips, slender eyes that gaze down at his hands, and furrowed brows. He is bald and is colored black on the top part of his body and golden colored on the bottom part.',
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '768331',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768331',
#      'alttext': 'A wooden sculpture of a young boy standing upright. The boy is wearing a long, red piece of clothing that goes from his hips and covers his feet. His hands are together in front of his chest. The boy is bald and is looking down at his hands.',
#      'width': 1901,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/457648678',
#      'height': 2550}],
#    'begindate': '2019-05-25',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5756,
#    'title': 'Prince Shōtoku: The Secrets Within',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768331',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Rachel Saunders',
#      'name': 'Rachel Saunders',
#      'personid': 62111,
#      'displayorder': 1}],
#    'temporalorder': 4717,
#    'url': 'https://harvardartmuseums.org/exhibitions/5756/prince-shotoku-the-secrets-within',
#    'textiledescription': 'This exhibition gives visitors the rare chance to encounter a significant 13th-century Japanese icon, "_Prince Shōtoku at Age Two_":https://www.harvardartmuseums.org/collections/object/209642, from the inside out. Legendary prince Shōtoku Taishi (c. 574–622) is regarded as the founder of Buddhism in Japan. At two years old (one by the Western count), he was believed to have taken several steps forward, faced east, put his hands together, and praised the Buddha. A sacred relic, the eyeball of the Buddha, then appeared between his hands. The diminutive life-size sculpture—the oldest and finest of its kind—depicts that miraculous moment.\r\n\r\nThis striking sculpture is remarkable not only for its seemingly animated presence, but also for the cache of more than 70 objects contained within the hollow body cavity. Sealed inside a veritable time capsule for over 700 years, these objects—relic grains, sutras, miniature sculptures, and scraps of paper inscribed with personalized poems and prayers—were carefully removed in the early 20th century. One of the most important objects from the group, an extremely rare printed Lotus Sutra dating to the Southern Song period (c. 1160), was subsequently gifted to the Library of Congress in Washington, D.C. Thanks to the generosity of the Library of Congress, this exhibition reunites the Sutra with the remaining ensemble for the first time in over 70 years.\r\n\r\nAlso featured in the exhibition is the spectacular 14th-century painting _The Legendary Biography of Prince Shōtoku_, on loan from the Museum of Fine Arts, Boston. The painting relates several miraculous incidents from the prince’s early life.\r\n\r\nCurated by Rachel Saunders, Abby Aldrich Rockefeller Associate Curator of Asian Art, Harvard Art Museums.\r\n\r\nThis exhibition was made possible in part by the Robert H. Ellsworth Bequest to the Harvard Art Museums. Additional support was provided by Harvard University’s Edwin O. Reischauer Institute of Japanese Studies and by the Harvard Art Museums’ Leopold (Harvard M.B.A. ’64) and Jane Swergold Asian Art Exhibitions and Publications Fund and José Soriano Fund. Support for related programming provided by the Robert and Margaret Rothschild Lecture Fund.\r\n\r\nh3. *Online Resources*\r\n\r\np((. A "digital tool":https://www.hvrd.art/prince on the museums’ website allows visitors to learn more about the individual objects from within the sculpture, drawing on recent research and conservation efforts.\r\n\r\np((. Learn more about the exhibition in our series of short videos available on "Vimeo":https://vimeo.com/showcase/6016305.',
#    'enddate': '2019-08-11',
#    'venues': [{'country': None,
#      'begindate': '2019-05-25',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-08-11',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3610',
#        'galleryid': 3610,
#        'name': 'University Teaching Gallery',
#        'floor': 3}]}],
#    'id': 5756,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:768331',
#     'caption': 'Prince Shōtoku at Age Two, Japanese, Kamakura period, datable to c. 1292. Wood (hinoki cypress) with polychromy; inlaid rock crystal (quartz) eyes. Harvard Art Museums/Arthur M. Sackler Museum, Partial and promised gift of Walter C. Sedgwick in memory of Ellery Sedgwick Sr. and Ellery Sedgwick Jr., 2019.122.'}},
#   {'shortdescription': None,
#    'images': [{'date': '2018-08-03',
#      'copyright': 'Stiftung Arp e.V., Berlin/Rolandswerth',
#      'imageid': 490390,
#      'idsid': 454627309,
#      'format': 'image/jpeg',
#      'caption': 'Hans Arp relief as displayed in Harkness Commons Dining Room, Harvard University, c. 1950. Stiftung Arp e.V., Berlin/Rolandswerth. Photo: D. H. Wright.',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'LEG268757',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG268757',
#      'alttext': None,
#      'width': 2550,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/454627309',
#      'height': 1590}],
#    'begindate': '2019-02-08',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5755,
#    'title': 'Hans Arp’s Constellations II',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG268757',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Laura Muir',
#      'name': 'Laura Muir',
#      'personid': 1274,
#      'displayorder': 1}],
#    'temporalorder': 4703,
#    'url': 'https://harvardartmuseums.org/exhibitions/5755/hans-arps-constellations-ii',
#    'textiledescription': 'This exhibition presents the room-sized wall relief "_Constellations II_":https://hvrd.art/o/56779 by Alsatian artist and poet Hans Arp (1886–1966); it is the work’s first public viewing in 15 years. Commissioned for the Harvard Graduate Center by Harvard architecture professor and Bauhaus founding director Walter Gropius, the relief’s 13 panels were first installed in 1950 on facing walls of a popular dining room in Harkness Commons (now the Caspersen Center). Arp described its biomorphic shapes as primal forms inspired by nature, a connection made clear in the title of the work, which evokes a grouping of stars in the night sky. _Constellations II_ inaugurated a new chapter in Arp’s postwar practice. It was his first large-scale, site-specific artwork and led to others, including a metal relief for the UNESCO headquarters in Paris. \r\n\r\nBy 1958, heavy use of the Harkness dining room had caused damage to the relief, prompting a new placement of the work above table height. Subsequent painting campaigns transformed the panels’ stained redwood finish to gray-blue, then to white, and back to natural. With the cooperation of Harvard Law School, which transferred the relief to the Harvard Art Museums in 2017, the Straus Center for Conservation and Technical Studies undertook a yearlong conservation initiative to restore the work to its original finish. \r\n\r\nThe presentation of _Constellations II_ coincides with "_The Bauhaus and Harvard_":https://www.harvardartmuseums.org/visit/exhibitions/5615/the-bauhaus-and-harvard, the museums’ Spring 2019 special exhibition mounted in conjunction with the 100th anniversary of the founding of the Bauhaus. The exhibition features nearly 200 objects from the Busch-Reisinger Museum’s historic Bauhaus collection. \r\n\r\nCurated by Melissa Venator, 2016–19 Stefan Engelhorn Curatorial Fellow in the Busch-Reisinger Museum. \r\n\r\nSupport for this exhibition was provided by the Daimler Curatorship of the Busch-Reisinger Museum Fund, the Charles L. Kuhn Endowment Fund, and the Care of the Busch-Reisinger Museum Collection Endowment. Modern and contemporary art programs at the Harvard Art Museums are made possible in part by generous support from the Emily Rauh Pulitzer and Joseph Pulitzer, Jr., Fund for Modern and Contemporary Art. We also wish to thank our colleagues at the Harvard Law School for their collaboration. \r\n\r\nShare your experience: #Bauhaus100 #HarvardArtMuseums \r\n\r\n*Online Resources* \r\n\r\nThe museums’ self-guided Art + Science "digital tool":https://www.harvardartmuseums.org/tour/art-science/stop/2100 provides more information on the history of Arp\'s _Constellations II_ and its recent restoration. \r\n\r\nWatch curatorial fellow Melissa Venator and conservation fellow Madeline Corona explain the creation, evolution, and restoration of _Constellations II_ in a short video on "Vimeo":https://vimeo.com/318813926. \r\n\r\nA comprehensive "digital resource":https://www.harvardartmuseums.org/collections/special-collections/the-bauhaus launched in 2016 provides access to the museums’ more than 32,000 Bauhaus-related objects and shares scholarship on the school’s extensive ties to Harvard and the Greater Boston area. \r\n\r\n*Related Exhibitions at Harvard and Beyond* \r\n\r\n"_The Bauhaus and Harvard_":https://harvardartmuseums.org/exhibitions/5615/the-bauhaus-and-harvard\r\nFebruary 8, 2019–July 28, 2019\r\nSpecial Exhibitions Gallery, Harvard Art Museums \r\n\r\n"_The Bauhaus at Home and Abroad: Selections from the Papers of Walter Gropius, Lyonel Feininger, and Andor Weininger_":https://library.harvard.edu/events/bauhaus-home-and-abroad\r\nJanuary 15–May 31, 2019\r\nAmy Lowell Room, Houghton Library, Harvard University \r\n\r\n"_Creating Community: Harvard Law School and the Bauhaus_":https://exhibits.law.harvard.edu/creating-community-harvard-law-school-and-bauhaus\r\nFebruary 4–August 16, 2019\r\nCaspersen Room, Langdell Hall, Harvard Law School ...
#    'enddate': '2019-07-28',
#    'venues': [{'country': None,
#      'begindate': '2019-02-08',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-07-28',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3600',
#        'galleryid': 3600,
#        'name': 'University Research Gallery',
#        'floor': 3}]}],
#    'id': 5755,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG268757',
#     'caption': 'Hans Arp relief as displayed in Harkness Commons Dining Room, Harvard University, c. 1950. Stiftung Arp e.V., Berlin/Rolandswerth. Photo: D. H. Wright.'}},
#   {'shortdescription': None,
#    'images': [{'date': '2018-01-12',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 483079,
#      'idsid': 459572233,
#      'format': 'image/jpeg',
#      'caption': 'Herbert Bayer, Design for a Multimedia Trade Fair Booth, 1924. Opaque watercolor, charcoal and touches of graphite with collage of cut printed and colored papers on off-white wove paper. Harvard Art Museums/Busch-Reisinger Museum, Gift of the artist, BR48.101. © Artists Rights Society (ARS), New York/VG Bild-Kunst, Bonn.',
#      'description': 'A cube shaped building is seen from above and at an angle to show three sides. A small photograph of a man in a suit emerges from a doorway at the lower left corner of the front. Below him, small red arrows indicate exit or entrance on either side of the divided door. A woman’s face is on a large sign on the left side of the cube. The word “Regina” appears three times on and around the cube: on the front emerging from a phonograph horn, along the far edge of the left face, and also from a hole in the roof, in the form of smoke clouds that form the letters.',
#      'technique': 'Make:Hasselblad;Model:Hasselblad H5D-50c MS;Orientation:1;Software:Adobe Photoshop CS6 (Macintosh);',
#      'renditionnumber': '765637',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:765637',
#      'alttext': 'A stylized plan for a brightly colored booth in the shape of a cube.',
#      'width': 2195,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/459572233',
#      'height': 2550}],
#    'begindate': '2019-02-08',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5615,
#    'videos': [{'description': 'Bauhaus Opening Lecture (Livestream)',
#      'videoid': 503381,
#      'primaryurl': 'https://vimeo.com/316851410'}],
#    'title': 'The Bauhaus and Harvard',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:765637',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Laura Muir',
#      'name': 'Laura Muir',
#      'personid': 1274,
#      'displayorder': 1}],
#    'temporalorder': 4702,
#    'url': 'https://harvardartmuseums.org/exhibitions/5615/the-bauhaus-and-harvard',
#    'textiledescription': '_The Bauhaus and Harvard_ — mounted in conjunction with the 100th anniversary of the founding of the Bauhaus in Weimar, Germany — presents nearly 200 works by 74 artists, drawn almost entirely from the Busch-Reisinger Museum’s extensive Bauhaus collection. Founded in 1919 and closed just 14 years later, the Bauhaus was the 20th century’s most influential school of art, architecture, and design. Harvard University played host to the first Bauhaus exhibition in the United States in 1930, and went on to become an unofficial center for the Bauhaus in America when founding director Walter Gropius joined Harvard’s department of architecture in 1937. Today the Busch-Reisinger Museum houses the largest Bauhaus collection outside Germany, initiated and assembled through the efforts of Gropius and many former teachers and students who emigrated from Nazi Germany, including Anni and Josef Albers, Herbert Bayer, Lyonel Feininger, and László Moholy-Nagy. \r\n\r\nThe exhibition features rarely seen student exercises, iconic design objects, photography, textiles, typography, paintings, and archival materials. It explores the school’s pioneering approach to art education, the ways its workshops sought to revolutionize the experience of everyday life, the widespread influence of Bauhaus instruction in America, and Harvard’s own Graduate Center (1950), the first modernist building complex on campus, designed by Gropius’s firm The Architects Collaborative. A complementary exhibition installed in an adjacent gallery — "_Hans Arp’s Constellations II_":https://www.harvardartmuseums.org/visit/exhibitions/5755/hans-arps-constellations-ii — features one of the site-specific works commissioned for the Graduate Center. A publication inspired by _The Bauhaus and Harvard_ and its related programming is due out in March 2021. \r\n\r\nOrganized by the Harvard Art Museums. Curated by Laura Muir, Research Curator in the Division of Academic and Public Programs, Harvard Art Museums. \r\n\r\nSupport for this project is provided by endowed funds, including the Daimler Curatorship of the Busch-Reisinger Museum Fund, the Charles L. Kuhn Endowment Fund, and the Care of the Busch-Reisinger Museum Collection Fund. The publication is supported by the Harvard Art Museums Mellon Publication Funds, including the Carola B. Terwilliger Fund. In addition, exhibition related programming is made possible by the M. Victor Leventritt Fund, which was established through the generosity of the wife, children, and friends of the late M. Victor Leventritt, Harvard Class of 1935. Modern and contemporary art programs at the Harvard Art Museums are made possible in part by generous support from the Emily Rauh Pulitzer and Joseph Pulitzer, Jr., Fund for Modern and Contemporary Art. \r\n\r\nShare your experience: #Bauhaus100 #HarvardArtMuseums \r\n\r\n*Online Resources* \r\n\r\nA comprehensive "digital resource":https://www.harvardartmuseums.org/collections/special-collections/the-bauhaus launched in 2016 provides access to the museums’ more than 32,000 Bauhaus-related objects and shares scholarship on the school’s extensive ties to Harvard and the Greater Boston area. \r\n\r\nLearn more about the exhibition in our series of "videos on Vimeo":https://vimeo.com/channels/1441937/page:1, including an introduction by Laura Muir, a recording of artist Judith Raum\'s lecture-performance evoking the figure of Bauhaus weaver Otti Berger during the exhibition\'s opening celebration, presentations from the symposium "Bauhaus 100: Object Lessons from a Historic Collection," and more. \r\n\r\n*Related Exhibitions at Harvard and Beyond* \r\n\r\n"_Hans Arp’s Constellations II_":https://www.harvardartmuseums.org/visit/exhibitions/5755/hans-arps-constellations-ii\r\nFebruary 8, 2019–July 28, 2019\r\nUniversity Research Gallery, Harvard Art Museums \r\n\r\n"_Judith Raum: Raveled Fabrics_":https://www.harvardartmuseums.org/visit/exhibitions/5858/judith-raum-raveled-fabrics\r\nFeb ...
#    'enddate': '2019-07-28',
#    'venues': [{'country': None,
#      'begindate': '2019-02-08',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-07-28',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3500',
#        'galleryid': 3500,
#        'name': 'Special Exhibitions Gallery',
#        'floor': 3}]}],
#    'id': 5615,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:765637',
#     'caption': 'Herbert Bayer, Design for a Multimedia Trade Fair Booth, 1924. Opaque watercolor, charcoal and touches of graphite with collage of cut printed and colored papers on off-white wove paper. Harvard Art Museums/Busch-Reisinger Museum, Gift of the artist, BR48.101. © Artists Rights Society (ARS), New York/VG Bild-Kunst, Bonn.'},
#    'publications': [{'publicationplace': 'Cambridge',
#      'shortdescription': None,
#      'publicationyear': 2021,
#      'format': 'Book',
#      'description': 'Founded by architect Walter Gropius (1883–1969) in 1919, the Bauhaus was the 20th century’s most influential school of art, architecture, and design. After the school was shuttered under pressure from the Nazis in 1933, many Bauhaus artists brought their innovative practices and teaching methods to the United States. Gropius himself accepted a position at Harvard, where he would help establish a collection of Bauhaus material that has since grown to more than 30,000 objects—the largest such collection outside Germany. Harvard in turn became an unofficial center for the Bauhaus in America. Written by established and emerging voices in the field, the scholarship presented here expands on the special link between the two institutions, while highlighting understudied aspects of the Bauhaus, such as weaving, photography, and art made by women. Accompanied by beautiful illustrations—some of never-before-published objects—this book yields fascinating insights for Bauhaus devotees and design aficionados.\u3000A full reproduction of the six-page catalogue produced by the Harvard Society for Contemporary Art for its 1930 exhibition—the first Bauhaus exhibition in the United States—is included at the back of the book. \r\n\r\nLaura Muir is Associate Director of Academic and Public Programs and the Louis Miller Thayer Research Curator at the Harvard Art Museums.\r\nWith contributions by Francesca G. Bewer, Annie Bourneuf, Katarina Burin, Madeline Corona, Susan D. Costello, Katherine Eremin, Laura A. Frahm, Teri Hensick, Fritz Horstman, Kristie La, Laura Muir, Georgina Rayner, Jeffrey Saletnik, Robin Schuldenfrei, Kate Smith, Jordan Troeller, Melissa Venator, and Robert Wiesenberger.\r\nObject Lessons was inspired by the exhibition The Bauhaus and Harvard and its related programming offered during Spring/Summer 2019, which coincided with the 100th anniversary of the founding of the Bauhaus. Explore more than 32,000 Bauhaus-related objects in the museums’ online resource The Bauhaus: hvrd.art/bauhaus',
#      'publicationid': 25228,
#      'title': 'Object Lessons: The Bauhaus and Harvard',
#      'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG275578',
#      'publicationdate': '2021'}]},
#   {'shortdescription': None,
#    'images': [{'date': '2019-01-22',
#      'copyright': ' Image courtesy of the artist. © Judith Raum, 2017.',
#      'imageid': 494771,
#      'idsid': 460628994,
#      'format': 'image/jpeg',
#      'caption': 'Judith Raum, Still image from the video Taking Turns on the Same Loom, 2017. Image: Courtesy of the artist. © 2017 Judith Raum. Textile pictured is Gunta Stölzl, Tapestry, 1922–23. Harvard Art Museums/Busch-Reisinger Museum, Association Fund, BR49.669. © Artists Rights Society (ARS), New York/VG Bild-Kunst, Bonn.',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'LEG270013',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270013',
#      'alttext': None,
#      'width': 2550,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/460628994',
#      'height': 1434}],
#    'begindate': '2019-02-07',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5858,
#    'title': 'Judith Raum: Raveled Fabrics',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270013',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Melissa Venator',
#      'name': 'Melissa Venator',
#      'personid': 63252,
#      'displayorder': 1}],
#    'temporalorder': 4701,
#    'url': 'https://harvardartmuseums.org/exhibitions/5858/judith-raum-raveled-fabrics',
#    'textiledescription': 'Historically overlooked, the Bauhaus weaving workshop was a site of technical innovation, artistic expression, and theoretical inquiry. Judith Raum places the workshop and its predominantly female weavers at the center of two films on view in the Lightbox Gallery.\r\n\r\nArchival photographs and close-ups of fabrics show the material and structural complexity that Bauhaus weavers achieved while also relating these tactile qualities to the institutional politics and aesthetics of their time. Raum’s films are a result of her extensive research on Bauhaus fabrics in European archives and here at Harvard’s Busch-Reisinger Museum, which houses the largest Bauhaus collection outside Germany. \r\n\r\nA Berlin-based artist and author, Raum creates installations and presents lecture-performances based on archival research and investigations into social and economic history. She made the films in this exhibition as part of a larger project on the Bauhaus weaving workshop, _Bauhaus Space_ (2017), commissioned by Germany’s _ifa_ Institut für Auslandsbeziehungen for the exhibition _The Event of a Thread_. Selected wall hangings and fabrics pictured in the films are featured in the exhibition "_The Bauhaus and Harvard_":https://www.harvardartmuseums.org/visit/exhibitions/5615/the-bauhaus-and-harvard, on view at the Harvard Art Museums from February 8–July 28, 2019. \r\n\r\n_Judith Raum: Raveled Fabrics_ is presented in the Lightbox Gallery, an experimental space for digital research and development at the Harvard Art Museums. Developed in collaboration with faculty, staff, students, and visiting artists, projects in the Lightbox Gallery challenge how we document, share, and examine collections and collections data. Some of these projects are responsive, allowing users to navigate and manipulate the collections; others are cinematic, transforming the museums into a landscape of digital performance.\r\n\r\n*Online Resources*\r\n\r\n"Watch":https://vimeo.com/316851410 Judith Raum present a lecture-performance evoking the figure of Bauhaus weaver Otti Berger, in conjunction with the opening celebration of _The Bauhaus and Harvard_ held on February 7, 2019.\r\n\r\nA comprehensive "digital resource":https://www.harvardartmuseums.org/collections/special-collections/the-bauhaus launched in 2016 provides access to the museums’ more than 32,000 Bauhaus-related objects and shares scholarship on the school’s extensive ties to Harvard and the Greater Boston area.',
#    'enddate': '2019-03-17',
#    'venues': [{'country': None,
#      'begindate': '2019-02-07',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-03-17',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '5000',
#        'galleryid': 5000,
#        'name': 'Lightbox Gallery',
#        'floor': 5}]}],
#    'id': 5858,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG270013',
#     'caption': 'Judith Raum, Still image from the video Taking Turns on the Same Loom, 2017. Image: Courtesy of the artist. © 2017 Judith Raum. Textile pictured is Gunta Stölzl, Tapestry, 1922–23. Harvard Art Museums/Busch-Reisinger Museum, Association Fund, BR49.669. © Artists Rights Society (ARS), New York/VG Bild-Kunst, Bonn.'}},
#   {'shortdescription': None,
#    'images': [{'date': None,
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 38534,
#      'idsid': 460189176,
#      'format': 'image/jpeg',
#      'caption': 'Hanns Dustmann, Walter Gropius, and Franz Möller, Club House, Argentina, 1931–1932: Site plan and perspectives, 1931–32. Photomechanical print with ink and blue wash on paper. Harvard Art Museums/Busch-Reisinger Museum, Gift of Walter Gropius, BRGA.60.6.',
#      'description': None,
#      'technique': 'Ektachrome Professional',
#      'renditionnumber': '82856',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS82856_dynmc',
#      'alttext': None,
#      'width': 2550,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/460189176',
#      'height': 1800}],
#    'begindate': '2019-01-26',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5830,
#    'title': 'Displaying Latin America',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS82856_dynmc',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Laura Muir',
#      'name': 'Laura Muir',
#      'personid': 1274,
#      'displayorder': 1}],
#    'temporalorder': 4699,
#    'url': 'https://harvardartmuseums.org/exhibitions/5830/displaying-latin-america',
#    'textiledescription': 'The Americas were a vital stage of transatlantic encounters in modern architecture. Mobility of ideas, peoples, and works established intellectual and material networks that constructed modern architecture as an international event. This exhibition explores the vibrant cosmopolitan architecture culture in Latin America during the interwar period, using original materials from archival collections at Harvard. Presented here are works by Argentinian architects Jorge Ferrari Hardoy and Juan Kurchan, who collaborated with Le Corbusier, and by German architect Franz Möller, who worked with Walter Gropius, both of whom were key propagandists of modern architecture.\r\n\r\nIn 1931, Möller opened the office Gropius-Moller Arquitectos in Buenos Aires. Among the firm’s projects was the Ciudad Balnearia de Chapadmalal, a private commission for a large-scale seaside resort, represented here by the clubhouse. This high-end leisure development contrasts with Gropius Standard—a one-story, low-cost house intended for young professional couples that could transform over time to meet the needs of a growing family. This system continued Gropius’s interests in prefabrication, which can be traced back to his Bauhaus years, but was adjusted to suit local building and climatic conditions.\r\n\r\nIn the early 1940s, Ferrari Hardoy and Kurchan conceived of an apartment building on Virrey del Pino Street to showcase the possibilities of “city in the park” modern planning; they envisioned the project as a fragment of a future greater whole. The 10-story apartment block is set back on an urban lot, and an ample garden separates the building from the street. Three august carefully preserved eucalyptus trees were woven into the facade, fusing practical climatic considerations and formal aesthetic concerns. Both architects were engaged in the Plan Director, a master plan for the Argentinian capital that had been developed with Le Corbusier in Paris. Le Corbusier’s daring proposal for skyscrapers on the Rio de la Plata, which had sprung from his 1929 visit to Argentina, would have extended the city of the Pampas into the river. This key functional and symbolic node sets the development of the Plan Director into a multinode city linked by circulation arteries. After the war, working for the city government, Ferrari Hardoy and Kurchan refined the plan and vigorously endeavored to publicize and implement it.\r\n\r\nThis installation’s related course is taught by Patricio del Real, Assistant Professor of the History of Art and Architecture, Harvard University.\r\n\r\nThe University Teaching Gallery serves faculty and students affiliated with Harvard’s Department of History of Art and Architecture. Semester-long installations are mounted here in conjunction with undergraduate and graduate courses, supporting instruction in the critical analysis of art and making unique selections from the museums’ collections available to all visitors.\r\n\r\nThis installation is made possible in part by funding from the Department of History of Art and Architecture. Modern and contemporary art programs at the Harvard Art Museums are made possible in part by generous support from the Emily Rauh Pulitzer and Joseph Pulitzer, Jr., Fund for Modern and Contemporary Art.\r\n\r\nThanks to the Frances Loeb Library at the Harvard Graduate School of Design for generously loaning works from the library’s Jorge Ferrari Hardoy Archive.',
#    'enddate': '2019-05-12',
#    'venues': [{'country': None,
#      'begindate': '2019-01-26',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-05-12',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3610',
#        'galleryid': 3610,
#        'name': 'University Teaching Gallery',
#        'floor': 3}]}],
#    'id': 5830,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:VRS82856_dynmc',
#     'caption': 'Hanns Dustmann, Walter Gropius, and Franz Möller, Club House, Argentina, 1931–1932: Site plan and perspectives, 1931–32. Photomechanical print with ink and blue wash on paper. Harvard Art Museums/Busch-Reisinger Museum, Gift of Walter Gropius, BRGA.60.6.'}},
#   {'shortdescription': None,
#    'images': [{'date': '2018-11-09',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 493133,
#      'idsid': 459802696,
#      'format': 'image/jpeg',
#      'caption': None,
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'LEG269109',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG269109',
#      'alttext': None,
#      'width': 2550,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/459802696',
#      'height': 1700}],
#    'begindate': '2018-10-30',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5790,
#    'title': 'Jace Clayton, The Great Salt',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG269109',
#    'temporalorder': 4691,
#    'url': 'https://harvardartmuseums.org/exhibitions/5790/jace-clayton-the-great-salt',
#    'textiledescription': 'In 1638, a work of silver known as "_The Great Salt_":https://www.harvardartmuseums.org/collections/object/232296  arrived in the Massachusetts Bay Colony. Owned by John Glover, who died during his passage across the Atlantic, the object transferred to Glover’s widow Elizabeth, who later married Henry Dunster, the first president of Harvard. _The Great Salt_ (on display in the silver cabinet on Level 2, "Gallery 2340":https://www.harvardartmuseums.org/visit/floor-plan/2/2340?gallery=2340) is one of seven pieces of historic Harvard silver. This shape-shifting container, designed to hold salt for the dining table at a time when the mineral was a rare and valuable commodity, is invested with centuries of prestige. Originally the charge of the most important person sitting at the table, _The Great Salt_ continued to be used throughout the 20th century as part of the regalia for inauguration ceremonies of new Harvard presidents.\r\n\r\nThis object was selected by Jace Clayton, a visiting artist at the Harvard Art Museums, as the subject for a digital response—a sonic extension and intervention into _The Great Salt_’s narrative. A display vitrine, much like those that protect precious objects elsewhere in the museums, here holds approximately 40 electronic synthesizer modules, connected with multicolored cables. Programmed using granular synthesis, a technique that breaks a sound into tiny “grains,” this collection of electronic components performs a new work—a composition designed by Clayton to self-modulate, actively generating new sounds and changing as it repeats. Three marímbulas—Afro-Cuban thumb pianos—surround the vitrine and can be played by visitors, affecting the presentation of the electronic sound.\r\n\r\nThe year 1638, just as _The Great Salt_ made its way to Massachusetts, was also when the first enslaved Africans arrived in the colony. This installation includes references to both 17th-century European and African musical forms, playing with associations between _The Great Salt_, the sea, and the Middle Passage. Through sound, the installation responds to _The Great Salt_ with acts of performance, translation, and participation.\r\n\r\nJace Clayton, Harvard College class of ’97, is an artist and writer based in New York City. Also known for his performances as DJ /rupture, Clayton creates interdisciplinary works that explore interactions among sound, memory, and public space. His sonic experiments have been exhibited at the Andy Warhol Museum and Barnes Foundation, and his works travel internationally in the form of music, writing, and frequent live performances. Clayton joined the faculty of Bard College in 2013 and recently served as the Nannerl Keohane Distinguished Visiting Professor at the University of North Carolina at Chapel Hill and Duke University. He has been an artist-in-residence with the Lower Manhattan Cultural Council and the Eyebeam Art + Technology Atelier, as well as a USC Annenberg/Getty Arts Journalism Fellow. He is the author of _Uproot: Travels in 21st-Century Music and Digital Culture_ (Farrar, Straus and Giroux, 2016).\r\n\r\n*Online Resources*\r\n"Watch a performance":https://vimeo.com/album/5633618 of _Salt Wood Salt Wire Salt Salt_, a new composition by Jace Clayton. This companion piece to the installation _Jace Clayton, The Great Salt_ was written expressly for—and performed with—the new music ensemble Bent Duo (David Friend, piano; Bill Solomon, percussion) and features Clayton’s live electronics. The performance was recorded on Thursday, December 6, 2018 in Adolphus Busch Hall at the Harvard Art Museums.',
#    'enddate': '2019-02-04',
#    'venues': [{'country': None,
#      'begindate': '2018-10-30',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-02-04',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '5000',
#        'galleryid': 5000,
#        'name': 'Lightbox Gallery',
#        'floor': 5}]}],
#    'id': 5790,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG269109',
#     'caption': None}},
#   {'shortdescription': None,
#    'images': [{'date': '2018-06-04',
#      'copyright': 'British Museum',
#      'imageid': 487764,
#      'idsid': 444992764,
#      'format': 'image/jpeg',
#      'caption': 'Rhyton with the forepart of a griffin, Achaemenid, 5th–4th century BCE. Silver, partially gilded. The British Museum, London, Bequeathed by Sir Augustus Wollaston Franks, 1897,1231.178 (124081). Photo: © The Trustees of the British Museum. All rights reserved.',
#      'description': None,
#      'technique': None,
#      'renditionnumber': 'LEG261100',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG261100',
#      'alttext': None,
#      'width': 1914,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/444992764',
#      'height': 2550}],
#    'begindate': '2018-09-07',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5295,
#    'title': 'Animal-Shaped Vessels from the Ancient World: Feasting with Gods, Heroes, and Kings',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG261100',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by Susanne Ebbinghaus',
#      'name': 'Susanne Ebbinghaus',
#      'personid': 142,
#      'displayorder': 1}],
#    'temporalorder': 4677,
#    'url': 'https://harvardartmuseums.org/exhibitions/5295/animal-shaped-vessels-from-the-ancient-world-feasting-with-gods-heroes-and-kings',
#    'textiledescription': '_Animal-Shaped Vessels from the Ancient World: Feasting with Gods, Heroes, and Kings_ brings together nearly 60 elaborate vessels of animal shape from collections in the United States and Europe. While the songs, speeches, and prayers that enlivened ancient feasts are now largely lost to us, these vessels have survived, offering a glimpse into the rich symbolism and communal practices that found expression at these gatherings. Taking animal-shaped vessels as performative props in the multifaceted world of feasting, the exhibition not only introduces the social and ceremonial functions of these ritual occasions, but also highlights the essential and universal role played by food and drink—and by the highly imaginative containers used to enjoy these refreshments.\r\n\r\nThe exhibition includes vessels in the shape of standing or reclining animals, animal-headed cups and beakers, drinking horns, and animated pitchers. Various creatures, real and imagined, give these objects their shapes: powerful bulls and rams, majestic lions and mythical griffins, wild boars and goats, deer and gazelles, graceful birds, and braying donkeys, among others. Assembling such a range of vessels for the first time, the exhibition presents a cross-cultural and cross-disciplinary examination of how they spanned geography and time, across three continents and over three millennia. The international menagerie of drinking and pouring vessels vividly illustrates not just how shapes and artistic forms crossed borders, but how ideas as well were exchanged among cultures—tangible evidence of close contact and the intermingling of traditions.\r\n\r\nBeyond their role in ritual and ceremonial drinking, animal-shaped vessels functioned variously as diplomatic gifts and tribute, the spoils of war, offerings to deities and the dead, and exotic objects of trade; they also were prized and emulated as symbols of status and prestige. Each object in the exhibition is a compelling animal study in itself, with a wealth of information embedded in its material, shape, and decoration. Many were made of rare or innovative materials—including gold, silver, bronze, glass, faience, and horn—and at the hands of skilled artists. They conveyed important information about their liquid contents and the nature of a gathering, but were also markers of social stature, identity, etiquette, and shared values.\r\n\r\nMost of the objects in the exhibition belong to a tradition of animal-shaped drinking and pouring vessels that persisted in the Near East and the Mediterranean from the Bronze Age in the third and second millennia BCE to the advent of Islam in the seventh century; this tradition eventually extended all the way to China, via the Silk Road. Select animal-shaped vessels from other cultures and periods—including East Asia, Africa, Europe, and South America—provide further points of comparison. In addition to the vessels, the exhibition features several related objects (paintings and sculpture) with ancient and modern representations of feasts. More than 20 domestic and international institutions have generously lent objects to the exhibition, including the Ashmolean Museum (Oxford University), the British Museum (London), the Louvre (Paris), the Metropolitan Museum of Art (New York), and the Museum of Fine Arts (Boston).\r\n\r\nThe exhibition, curated by Susanne Ebbinghaus, the George M.A. Hanfmann Curator of Ancient Art and head of the Division of Asian and Mediterranean Art at the Harvard Art Museums, is accompanied by a full "catalogue":https://shop.harvardartmuseums.org/collections/frontpage/products/animal-shaped-vessels-from-the-ancient-world-feasting-with-gods-heroes-and-kings edited by Ebbinghaus.\r\n\r\nCrucial support for the _Animal-Shaped Vessels_ project has been made possible in part by a major grant from the "National Endowment for the Humanities: Exploring the Human Endeavor":https://www.neh.gov/. In addition, the Harvard Art Museums are d ...
#    'enddate': '2019-01-06',
#    'venues': [{'country': None,
#      'begindate': '2018-09-07',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-01-06',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3500',
#        'galleryid': 3500,
#        'name': 'Special Exhibitions Gallery',
#        'floor': 3}]}],
#    'id': 5295,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG261100',
#     'caption': 'Rhyton with the forepart of a griffin, Achaemenid, 5th–4th century BCE. Silver, partially gilded. The British Museum, London, Bequeathed by Sir Augustus Wollaston Franks, 1897,1231.178 (124081). Photo: © The Trustees of the British Museum. All rights reserved.'},
#    'publications': [{'publicationplace': 'Cambridge, MA',
#      'shortdescription': None,
#      'publicationyear': 2018,
#      'format': 'Exhibition Catalogue',
#      'description': None,
#      'publicationid': 23608,
#      'title': 'Animal-Shaped Vessels from the Ancient World: Feasting with Gods, Heroes, and Kings',
#      'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:LEG268617',
#      'publicationdate': '2018'}]},
#   {'shortdescription': None,
#    'images': [{'date': '2001-03-01',
#      'copyright': 'President and Fellows of Harvard College',
#      'imageid': 16790,
#      'idsid': 17386548,
#      'format': 'image/jpeg',
#      'caption': 'Théodore Géricault, Cattle Market, 1817. Oil on paper mounted on canvas. Harvard Art Museums/Fogg Museum, Bequest of Grenville L. Winthrop, 1943.242.',
#      'description': 'A crowd of gray and brown bulls is gathered on a patio behind a wood fence. Three light-skinned men stand among them. The men on the right and left are nude. The center man is clothed. He and the left-most man have red cloths over their shoulders. All three men are grabbing the bulls by the horns or legs. The left and central men hold sticks, and their arms are posed as if preparing to strike. The bull closest to the foreground has fallen to the ground. Behind the crowd is a pasture with a mountain in the distance.',
#      'technique': None,
#      'renditionnumber': '51249',
#      'displayorder': 1,
#      'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51249_dynmc',
#      'alttext': 'Three men wielding stick among crowd of bulls',
#      'width': 2158,
#      'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17386548',
#      'height': 2550}],
#    'begindate': '2018-09-01',
#    'color': None,
#    'description': None,
#    'exhibitionid': 5700,
#    'title': 'Mutiny: Works by Géricault',
#    'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51249_dynmc',
#    'people': [{'role': 'Curator',
#      'prefix': 'Curated by',
#      'displayname': 'Curated by A. Cassandra Albinson',
#      'name': 'A. Cassandra Albinson',
#      'personid': 56131,
#      'displayorder': 1}],
#    'temporalorder': 4676,
#    'url': 'https://harvardartmuseums.org/exhibitions/5700/mutiny-works-by-gericault',
#    'textiledescription': "_Mutiny: Works by Géricault_ explores compelling images by the Romantic period’s most influential artist, Théodore Géricault (1791–1824), whose powerful legacy endured long past his untimely death in his early thirties. Approximately 40 drawings, watercolors, lithographs, and paintings from the Harvard Art Museums collections, augmented by loans from three Boston-area collectors, tell a new story of this socially and politically engaged artist across a range of media.\r\n\r\nGéricault’s work both reflected and inflected the changes that took place during the Restoration period in Europe. Lasting from roughly 1815 to 1830, this was an ostensibly peaceful time in the aftermath of the French revolution and the Napoleonic wars; yet the continent was still recovering from the earlier violence, and the Industrial Revolution was making its presence felt through increased urbanization and the introduction of new technologies. Recognizing this turmoil, Géricault strove to represent the casual brutality at the center of modern life, forgoing mythological or religious subjects to focus squarely on the present. This interest appears not only in images of wounded soldiers and the urban poor, but also in works depicting men as they interacted with horses as well as in portrayals of animals in distress or at battle. _Mutiny_ considers Géricault as the prototype of the modern artist: rejecting the norms of society in order to expose its tensions and conflicts through depictions of competing extremes—physical strength and weakness.\r\n\r\nGéricault is today famed for his paintings, most notably _The Raft of the Medusa_ (now in the Louvre), but during his lifetime he was more widely known for his prints. In this exhibition, three of Géricault’s paintings will be presented alongside the lithographic prints that assured the artist’s posthumous fame. Capturing the world around him with a sense of vivid immediacy, Géricault’s drawings and watercolors are critical to understanding his goals as an artist, and the exhibition will feature 12 of these creations. \r\n\r\nCurated by A. Cassandra Albinson, Margaret S. Winthrop Curator of European Art; with contributions by Jessie Park, Rousseau Curatorial Fellow in European Art, and Ashley Hannebrink, Curatorial Graduate Student Intern in the Division of European and American Art, Harvard Art Museums.\r\n\r\nThis exhibition is made possible by funding from the Gurel Student Exhibition Fund. We also thank the three anonymous lenders, each of whom is dedicated to the study and appreciation of Géricault's work. ",
#    'enddate': '2019-01-06',
#    'venues': [{'country': None,
#      'begindate': '2018-09-01',
#      'address2': None,
#      'city': 'Cambridge',
#      'address1': '32 Quincy St.',
#      'ishamvenue': 1,
#      'zipcode': '02138',
#      'enddate': '2019-01-06',
#      'venueid': 55780,
#      'name': 'Harvard Art Museums',
#      'fullname': 'Harvard Art Museums',
#      'state': 'MA',
#      'galleries': [{'gallerynumber': '3600',
#        'galleryid': 3600,
#        'name': 'University Research Gallery',
#        'floor': 3}]}],
#    'id': 5700,
#    'lastupdate': '2022-05-16T04:57:39-0400',
#    'poster': {'imageurl': 'https://nrs.harvard.edu/urn-3:HUAM:51249_dynmc',
#     'caption': 'Théodore Géricault, Cattle Market, 1817. Oil on paper mounted on canvas. Harvard Art Museums/Fogg Museum, Bequest of Grenville L. Winthrop, 1943.242.'}}]}

# %% [markdown]
# 3. Write a *loop* or *list comprehension* in Python to retrieve data
#    for the first 5 pages of exhibitions data.

# %%
exhibit_records = []
for page in range(1, 6):
    param_values = {'type': 'past-exhibition','page': page}
    current_request = requests.get(exhibits_url, params = param_values).json()['records']
    exhibit_records.extend(current_request)
    
print(pd.DataFrame(exhibit_records))
# Out:
#                  shortdescription                         images  ...                         videos                   publications
# 0                            None  [{'date': '2019-03-18', 'c...  ...                            NaN                            NaN
# 1                            None  [{'date': '2018-05-30', 'c...  ...                            NaN                            NaN
# 2                            None  [{'date': '2018-08-29', 'c...  ...                            NaN                            NaN
# 3                            None  [{'date': '2018-08-03', 'c...  ...                            NaN                            NaN
# 4                            None  [{'date': '2018-01-12', 'c...  ...  [{'description': 'Bauhaus ...  [{'publicationplace': 'Cam...
# 5                            None  [{'date': '2019-01-22', 'c...  ...                            NaN                            NaN
# 6                            None  [{'date': None, 'copyright...  ...                            NaN                            NaN
# 7                            None  [{'date': '2018-11-09', 'c...  ...                            NaN                            NaN
# 8                            None  [{'date': '2018-06-04', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 9                            None  [{'date': '2001-03-01', 'c...  ...                            NaN                            NaN
# 10                           None  [{'date': '2005-04-18', 'c...  ...                            NaN                            NaN
# 11                           None  [{'date': '2018-06-29', 'c...  ...  [{'description': 'Marina I...                            NaN
# 12                           None  [{'date': '2018-03-15', 'c...  ...                            NaN                            NaN
# 13                           None  [{'date': '2016-10-17', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 14                           None                            NaN  ...                            NaN                            NaN
# 15                           None  [{'date': '2017-02-16', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 16                           None  [{'date': '2018-01-23', 'c...  ...                            NaN                            NaN
# 17                           None  [{'date': '2001-04-01', 'c...  ...                            NaN                            NaN
# 18                           None  [{'date': '2016-06-10', 'c...  ...  [{'description': 'Fernando...                            NaN
# 19                           None  [{'date': '2008-10-27', 'c...  ...                            NaN                            NaN
# 20                           None  [{'date': '2017-10-05', 'c...  ...                            NaN                            NaN
# 21                           None  [{'date': '2002-05-01', 'c...  ...                            NaN                            NaN
# 22                           None  [{'date': '2007-08-01', 'c...  ...                            NaN                            NaN
# 23                           None  [{'date': '2003-03-21', 'c...  ...                            NaN                            NaN
# 24                           None  [{'date': '2017-05-08', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 25                           None  [{'date': '2002-08-01', 'c...  ...  [{'description': 'Symposiu...                            NaN
# 26                           None  [{'date': '2016-07-05', 'c...  ...                            NaN                            NaN
# 27                           None  [{'date': '2017-03-29', 'c...  ...                            NaN                            NaN
# 28                           None  [{'date': '2015-03-22', 'c...  ...  [{'description': 'The Phil...  [{'publicationplace': 'Cam...
# 29                           None  [{'date': '2017-03-07', 'c...  ...                            NaN                            NaN
# 30  Harvard professor Ewa Laje...  [{'date': '2001-03-01', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 31  This exhibition features w...  [{'date': '2016-07-12', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 32                           None  [{'date': '2017-02-08', 'c...  ...                            NaN                            NaN
# 33                           None  [{'date': '2001-06-01', 'c...  ...                            NaN                            NaN
# 34                           None  [{'date': '2005-11-03', 'c...  ...                            NaN                            NaN
# 35                           None  [{'date': '2015-04-06', 'c...  ...  [{'description': 'Wolfgang...                            NaN
# 36                    In progress  [{'date': '2016-07-28', 'c...  ...                            NaN                            NaN
# 37                           None  [{'date': None, 'copyright...  ...                            NaN                            NaN
# 38                           None  [{'date': '2016-03-21', 'c...  ...                            NaN                            NaN
# 39                           None  [{'date': '2007-04-18', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 40                           None  [{'date': '2015-04-01', 'c...  ...                            NaN  [{'publicationplace': 'Cam...
# 41                           None  [{'date': '2016-01-12', 'c...  ...                            NaN                            NaN
# 42                           None  [{'date': '2002-07-01', 'c...  ...                            NaN                            NaN
# 43                           None  [{'date': '2007-02-27', 'c...  ...                            NaN                            NaN
# 44                           None  [{'date': '2006-01-18', 'c...  ...                            NaN                            NaN
# 45                           None  [{'date': '2015-10-29', 'c...  ...                            NaN                            NaN
# 46                           None  [{'date': '2014-08-12', 'c...  ...  [{'description': 'Teaser: ...  [{'publicationplace': 'Cam...
# 47                           None  [{'date': '2005-11-03', 'c...  ...                            NaN                            NaN
# 48                           None  [{'date': '1989-08-01', 'c...  ...                            NaN                            NaN
# 49  This multi-component insta...  [{'date': '2014-03-31', 'c...  ...                            NaN                            NaN
#
# [50 rows x 19 columns]

# %% [markdown]
# 4. Bonus (optional): Convert the data you retrieved into a pandas
#   `DataFrame` and save it to a `.csv` file.

# %%
pd.DataFrame(exhibit_records).to_csv('first_five_exhibits_csv.csv')

# %% [markdown]
# ## Parsing HTML if you have to
#
# <div class="alert alert-info">
# **GOAL: To retrieve information in HTML format and organize it into a spreadsheet.**
#
# 1. Make a request to the website server to retrieve the HTML
# 2. Inspect the HTML to determine the XPATHs that point to the data we want
# 3. Extract the information from the location the XPATHs point to and store in a dictionary
# 4. Convert from a dictionary to a .csv file
# </div>
#
# As we've seen, you can often inspect network traffic or other sources
# to locate the source of the data you are interested in and the API
# used to retrieve it. You should always start by looking for these
# shortcuts and using them where possible. If you are really lucky,
# you'll find a shortcut that returns the data as JSON. If you
# are not quite so lucky, you will have to parse HTML to retrieve the
# information you need.
#
# ### Document Object Model (DOM)
#
# To parse HTML, we need to have a nice tree structure that contains the whole HTML
# file through which we can locate the information. This tree-like structure is the
# **Document Object Model (DOM)**. DOM is a cross-platform and language-independent
# interface that treats an XML or HTML document as a tree structure wherein each node
# is an object representing a part of the document. The DOM represents a document with
# a logical tree. *Each branch of the tree ends in a node, and each node contains objects*.
# DOM methods allow programmatic access to the tree; with them one can change the structure,
# style or content of a document. The following is an example of DOM hierarchy in an HTML document:
#
# ![](images/DOM.png)

# %% [markdown]
# ### Retrieving HTML
#
# When I inspected the network traffic while interacting
# with <https://www.harvardartmuseums.org/visit/calendar> I didn't see
# any requests that returned JSON data. The best we can do appears to be
# <https://www.harvardartmuseums.org/visit/calendar?date=>, which
# unfortunately returns HTML.
#
# The first step is the same as before: we make at `GET` request.

# %%
museum_domain = 'https://www.harvardartmuseums.org'

calendar_path = 'calendar'

calendar_url = (museum_domain # recall that we defined museum_domain earlier
                  + "/"
                  + calendar_path)

print(calendar_url)

events = requests.get(calendar_url)
# Out:
# https://www.harvardartmuseums.org/calendar

# %% [markdown]
# As before we can check the headers to see what type of content we
# received in response to our request.

# %%
events.headers['Content-Type']
# Out:
# 'text/html; charset=UTF-8'

# %% [markdown]
# ### Parsing HTML using the lxml library
#
# Like JSON, HTML is structured; unlike JSON it is designed to be
# rendered into a human-readable page rather than simply to store and
# exchange data in a computer-readable format. Consequently, parsing
# HTML and extracting information from it is somewhat more difficult
# than parsing JSON.
#
# While JSON parsing is built into the Python `requests` library, parsing
# HTML requires a separate library. I recommend using the HTML parser
# from the `lxml` library; others prefer an alternative called
# `beautifulsoup4`.

# %%
from lxml import html

# convert a html text representation (`events.text`) into 
# a tree-structure (DOM) html representation (`events_html`)
events_html = html.fromstring(events.text)

# %% [markdown]
# ### Using XPath to extract content from HTML
#
# `XPath` is a tool for identifying particular elements withing a HTML
# document. The developer tools built into modern web browsers make it
# easy to generate `XPath`s that can be used to identify the elements of a
# web page that we wish to extract.
#
# We can open the HTML document we retrieved and inspect it using
# our web browser.

# %%
html.open_in_browser(events_html, encoding = 'UTF-8')
# encoding required
# Out:
# file://C:/Users/bjimenez/AppData/Local/Temp/tmpf37aoba7.html

# %% [markdown]
# ![](images/dev_tools_right_click.png)
#
# ![](images/dev_tools_inspect.png)
#
# Once we identify the element containing the information of interest we
# can use our web browser to copy the `XPath` that uniquely identifies
# that element.
#
# ![](images/dev_tools_xpath.png)
#
# Next we can use Python to extract the element of interest:

# %%
events_list_html = events_html.xpath('//*[@id="events_list"]/article')
# //*[@id="events_list"]/article[7]/div/div
# take out everything after article
# //*[@id="events_list"]/article

# %% [markdown]
# Let's just extract the second element in our events list.

# %%
second_event_html = events_list_html[1]
print(events_list_html)
# Out:
# [<Element article at 0x269eb7c1310>, <Element article at 0x269eb7c1ea0>, <Element article at 0x269eb7c14a0>, <Element article at 0x269eb7bd950>, <Element article at 0x269e4f46bd0>, <Element article at 0x269ec548770>, <Element article at 0x269ec5486d0>, <Element article at 0x269eb7ca630>, <Element article at 0x269eb6b5b80>, <Element article at 0x269eb6b5ae0>, <Element article at 0x269eb6b5c20>, <Element article at 0x269eb6b5bd0>, <Element article at 0x269eb6b5c70>, <Element article at 0x269eb6b5cc0>, <Element article at 0x269eb6b5d10>]

# %% [markdown]
# Once again, we can use a web browser to inspect the HTML we're
# currently working with - from the second event - and to figure out what we want to extract from
# it.

# %%
html.open_in_browser(second_event_html, encoding = 'UTF-8')
# Out:
# file://C:/Users/bjimenez/AppData/Local/Temp/tmp6dyu0uvi.html

# %% [markdown]
# As before, we can use our browser to find the xpath of the elements we
# want.
#
# ![](images/dev_tools_figcaption.png)
#
# (Note that the `html.open_in_browser` function adds enclosing `html`
# and `body` tags in order to create a complete web page for viewing.
# This requires that we adjust the `xpath` accordingly.)
#
# By repeating this process for each element we want, we can build a
# list of the xpaths to those elements.

# %%
# //*[@id="events_list"]/article[7]/div/figure/div/figcaption
# get caption under the image; element containe din the events list (after article in the xpath)

elements_we_want = {'figcaption': 'div/figure/div/figcaption',
                    'date': 'div/div/header/time',
                    'title': 'div/div/header/h2/a',
                    'time': 'div/div/div/p[1]/time',
                    'description': 'div/div/div/p[3]'
                    }

# %% [markdown]
# Finally, we can iterate over the elements we want and extract them.

# %%
second_event_values = {}
for key in elements_we_want.keys():
    element = second_event_html.xpath(elements_we_want[key])[0]
    second_event_values[key] = element.text_content().strip()

print(second_event_values)
# Out:
# {'date': 'Wednesday, May 18, 2022',
#  'description': 'Explore the Harvard Art Museums for free on May 18, in '
#                 'recognition of Art Museum Day and International Museum Day.',
#  'figcaption': 'Anneliese Hager, German, Untitled, 1950s–60s. Gelatin silver '
#                'print (photogram). Harvard Art Museums/Busch-Reisinger Museum, '
#                'Gift of the German Friends of the Busch-Reisinger Museum, '
#                '2018.323. © Estate of Anneliese Hager.',
#  'time': '10:00am - 5:00pm',
#  'title': 'Free Admission Day for Art Museum Day and International Museum Day'}

# %% [markdown]
# ### Iterating to retrieve content from a list of HTML elements
#
# So far we've retrieved information only for the second event. To
# retrieve data for all the events listed on the page we need to iterate
# over the events. If we are very lucky, each event will have exactly
# the same information structured in exactly the same way and we can
# simply extend the code we wrote above to iterate over the events list.
#
# Unfortunately, not all these elements are available for every event, so
# we need to take care to handle the case where one or more of these
# elements is not available. We can do that by **defining a function** that
# tries to retrieve a value and returns an empty string if it fails.
#
# If you're not familiar with Python functions, here's the basic syntax:

# %%
# anatomy of a function

def name_of_function(arg1, arg2, ...argn):  # define the function name and arguments
    <body of function>   # specify calculations
    return <result>      # output result of calculations

# %% [markdown]
# Here's an example of a simple function:

# %%
def square_fun(x):
    y = x**2 # exponentiation
    return y

square_fun(4)

# %% [markdown]
# Here's a function to perform our actual task:

# %%
def get_event_info(event, path):
    try:
        info = event.xpath(path)[0].text_content().strip()
    except:
        info = ''
    return info

# %% [markdown]
# Armed with this function, we can iterate over the list of events and
# extract the available information for each one.

# %%
all_event_values = {}
for key in elements_we_want.keys():
    key_values = []
    for event in events_list_html: 
        key_values.append(get_event_info(event, elements_we_want[key]))
    all_event_values[key] = key_values

# %% [markdown]
# For convenience we can arrange these values in a pandas `DataFrame`
# and save them as .csv files, just as we did with our exhibitions data earlier.

# %%
all_event_values = pd.DataFrame.from_dict(all_event_values)

all_event_values.to_csv("all_event_values.csv")

print(all_event_values)
# Out:
#   figcaption date title time description
# 0

# %% [markdown]
# ### Exercise 1
#
# **parsing HTML**
#
# In this exercise you will retrieve information about the physical
# layout of the Harvard Art Museums. The web page at
# <https://www.harvardartmuseums.org/visit/floor-plan> contains this
# information in HTML from.
#
# 1. Using a web browser (Firefox or Chrome recommended) inspect the
#    page at `https://www.harvardartmuseums.org/visit/floor-plan`. Copy
#    the `XPath` to the element containing the list of level
#    information. (HINT: the element if interest is a `ul`, i.e.,
#    `unordered list`.)
#
# 2. Make a `get` request in Python to retrieve the web page at
#    <https://www.harvardartmuseums.org/visit/floor-plan>. Extract the
#    content from your request object and parse it using `html.fromstring`
#    from the `lxml` library.

# %% [markdown]
# 3. Use your web browser to find the `XPath`s to the facilities housed on
#    level one. Use Python to extract the text from those `Xpath`s.

# %% [markdown]
# 4. Bonus (optional): Write a *for loop* or *list comprehension* in Python
#    to retrieve data for all the levels.

# %% [markdown]
# ## `Scrapy`: for large / complex projects
#
# Scraping websites using the `requests` library to make GET and POST
# requests, and the `lxml` library to process HTML is a good way to
# learn basic web scraping techniques. It is a good choice for small to
# medium size projects. For very large or complicated scraping tasks the
# `scrapy` library offers a number of conveniences, including
# asynchronous retrieval, session management, convenient methods for
# extracting and storing values, and more. More information about
# `scrapy` can be found at <https://doc.scrapy.org>.
#
# ## Browser drivers: a last resort
#
# It is sometimes necessary (or sometimes just easier) to use a web
# browser as an intermediary rather than communicate directly with a
# web service. This method of using a "browser driver" has the advantage
# of being able to use the javascript engine and session management features
# of a web browser; the main disadvantage is that it is slower and tends to
# be more fragile than using `requests` or `scrapy` to make requests directly
# from Python. For small scraping projects involving complicated sites
# with CAPTHAs or lots of complicated javascript using a browser driver
# can be a good option. More information is available at
# <https://www.seleniumhq.org/docs/03_webdriver.jsp>.

# %% [markdown]
# ## Wrap-up
#
# ### Feedback
#
# These workshops are a work in progress, please provide any feedback to: help@iq.harvard.edu
#
# ### Resources
#
# * IQSS
#     + Workshops: <https://www.iq.harvard.edu/data-science-services/workshop-materials>
#     + Data Science Services: <https://www.iq.harvard.edu/data-science-services>
#     + Research Computing Environment: <https://iqss.github.io/dss-rce/>
#
# * HBS
#     + Research Computing Services workshops: <https://training.rcs.hbs.org/workshops>
#     + Other HBS RCS resources: <https://training.rcs.hbs.org/workshop-materials>
#     + RCS consulting email: <mailto:research@hbs.edu>
